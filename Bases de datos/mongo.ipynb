# %%
from pymongo import MongoClient

import pandas as pd

# %%
cursor = MongoClient()   # no esta escrita la string de conexion

cursor
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
str_conn = 'mongodb://localhost:27017'   # str_con por defecto

cursor = MongoClient(str_conn)

cursor
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
futbol = cursor['Futbol']

# %%
db = cursor.futbol

# %%
cursor.list_database_names()
# Out:
# ['admin', 'companies', 'config', 'futbol', 'local']

# %%
collection = db['Jugadores']

# %%
# Importo mi csv
jugadores = pd.read_csv('../csv/csv_limpios/jugadores_completo.csv')

# %% [markdown]
# #### Preparo los datos

# %%
# Convierto mi dataframe en un diccionario
jugadores_dict = jugadores.to_dict('records')

# %%
# Inserto mi diccionario en la coleccion
collection.insert_many(jugadores_dict)

# %%
# Verifico que se haya insertado correctamente
collection.find_one()
# Out:
# {'_id': ObjectId('656dc7c4de86b9b413026cb5'),
#  'Jugador': 'Aaron Connolly',
#  'País': 'IRL',
#  'Posc': 'Delantero',
#  'Equipo': 'Brighton',
#  'Edad': 21,
#  'Nacimiento': 2000.0,
#  'PJ': 15.0,
#  'Titular': 8.0,
#  'Mín': 735.0,
#  'Gls.': 1.6666666666666667,
#  'Asistencias': 0.6666666666666666,
#  'Goles+Asistencias': 2.333333333333333,
#  'Tarjetas Amarillas': 0.0,
#  'Tarjetas Rojas': 0.0,
#  'Goles Esperados': 2.8000000000000003,
#  'Asistencias Esperadas': 0.2666666666666666,
#  'Valor de mercado': 3500000.0}

# %% [markdown]
# ### Pruebo querys

# %%
#intento usar querys
query = {'$and': [{'Edad': {'$lt': 26}},
                  {'Edad': {'$gt': 24}}
                 ]}

len(list(collection.find(query)))
# Out:
# 498

# %%
# ahora una query para valor de mercado menos a 10 millones
query = {'Valor de mercado': {'$lt': 10000000}}

list(collection.find(query))
# Out:
# [{'_id': ObjectId('656dc7c4de86b9b413026cb5'),
#   'Jugador': 'Aaron Connolly',
#   'País': 'IRL',
#   'Posc': 'Delantero',
#   'Equipo': 'Brighton',
#   'Edad': 21,
#   'Nacimiento': 2000.0,
#   'PJ': 15.0,
#   'Titular': 8.0,
#   'Mín': 735.0,
#   'Gls.': 1.6666666666666667,
#   'Asistencias': 0.6666666666666666,
#   'Goles+Asistencias': 2.333333333333333,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 2.8000000000000003,
#   'Asistencias Esperadas': 0.2666666666666666,
#   'Valor de mercado': 3500000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cb6'),
#   'Jugador': 'Aaron Cresswell',
#   'País': 'ENG',
#   'Posc': 'Defensa',
#   'Equipo': 'West Ham',
#   'Edad': 33,
#   'Nacimiento': 1989.0,
#   'PJ': 25.6,
#   'Titular': 24.6,
#   'Mín': 2188.6,
#   'Gls.': 1.0,
#   'Asistencias': 2.4,
#   'Goles+Asistencias': 3.4,
#   'Tarjetas Amarillas': 3.2,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.76,
#   'Asistencias Esperadas': 3.34,
#   'Valor de mercado': 1200000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cb9'),
#   'Jugador': 'Aaron Ramsey',
#   'País': 'ENG',
#   'Posc': 'Delantero',
#   'Equipo': 'Burnley',
#   'Edad': 30,
#   'Nacimiento': 1993.25,
#   'PJ': 14.0,
#   'Titular': 6.75,
#   'Mín': 619.0,
#   'Gls.': 1.25,
#   'Asistencias': 1.25,
#   'Goles+Asistencias': 2.5,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 1.7,
#   'Asistencias Esperadas': 1.225,
#   'Valor de mercado': 2500000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cbb'),
#   'Jugador': 'Aarón Escandell',
#   'País': 'ESP',
#   'Posc': 'PO',
#   'Equipo': 'Granada',
#   'Edad': 25,
#   'Nacimiento': 1995.0,
#   'PJ': 4.0,
#   'Titular': 3.6666666666666665,
#   'Mín': 334.6666666666667,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.6666666666666666,
#   'Tarjetas Rojas': 0.3333333333333333,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 1000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cbc'),
#   'Jugador': 'Aarón Martín',
#   'País': 'ESP',
#   'Posc': 'Defensa',
#   'Equipo': 'Espanyol',
#   'Edad': 26,
#   'Nacimiento': 1997.0,
#   'PJ': 19.33333333333333,
#   'Titular': 17.666666666666668,
#   'Mín': 1567.3333333333333,
#   'Gls.': 0.0,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 3.0,
#   'Tarjetas Rojas': 0.3333333333333333,
#   'Goles Esperados': 0.1,
#   'Asistencias Esperadas': 1.2999999999999998,
#   'Valor de mercado': 7000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cbd'),
#   'Jugador': 'Abdallahi Mahmoud',
#   'País': 'MTN',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Alavés',
#   'Edad': 20,
#   'Nacimiento': 2000.0,
#   'PJ': 2.5,
#   'Titular': 1.0,
#   'Mín': 109.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.5,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 500000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cbe'),
#   'Jugador': 'Abdel Abqar',
#   'País': 'MAR',
#   'Posc': 'Defensa',
#   'Equipo': 'Alavés',
#   'Edad': 24,
#   'Nacimiento': 1999.0,
#   'PJ': 11.0,
#   'Titular': 11.0,
#   'Mín': 989.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 3.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.2,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 1400000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cbf'),
#   'Jugador': 'Abdelhamid Sabiri',
#   'País': 'MAR',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Sampdoria',
#   'Edad': 25,
#   'Nacimiento': 1996.0,
#   'PJ': 16.0,
#   'Titular': 10.5,
#   'Mín': 981.0,
#   'Gls.': 2.5,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 3.5,
#   'Tarjetas Amarillas': 4.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 2.2,
#   'Asistencias Esperadas': 1.5,
#   'Valor de mercado': 2500000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cc0'),
#   'Jugador': 'Abderrahman Rebbach',
#   'País': 'ALG',
#   'Posc': 'Delantero',
#   'Equipo': 'Alavés',
#   'Edad': 25,
#   'Nacimiento': 1998.0,
#   'PJ': 11.0,
#   'Titular': 2.0,
#   'Mín': 297.0,
#   'Gls.': 1.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.4,
#   'Asistencias Esperadas': 0.7,
#   'Valor de mercado': 500000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cc2'),
#   'Jugador': 'Abdou Harroui',
#   'País': 'NED',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Frosinone',
#   'Edad': 25,
#   'Nacimiento': 1998.0,
#   'PJ': 16.0,
#   'Titular': 3.6666666666666665,
#   'Mín': 451.3333333333333,
#   'Gls.': 1.3333333333333333,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 1.3333333333333333,
#   'Tarjetas Amarillas': 1.3333333333333333,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 1.1666666666666667,
#   'Asistencias Esperadas': 0.2,
#   'Valor de mercado': 2700000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cc3'),
#   'Jugador': 'Abdoulay Diaby',
#   'País': 'MLI',
#   'Posc': 'Defensa',
#   'Equipo': 'Getafe',
#   'Edad': 29,
#   'Nacimiento': 1991.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 18.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.3,
#   'Asistencias Esperadas': 0.1,
#   'Valor de mercado': 1200000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cc4'),
#   'Jugador': 'Abdoulaye Ba',
#   'País': 'SEN',
#   'Posc': 'Defensa',
#   'Equipo': 'Rayo Vallecano',
#   'Edad': 27,
#   'Nacimiento': 1991.0,
#   'PJ': 26.0,
#   'Titular': 25.0,
#   'Mín': 2110.0,
#   'Gls.': 1.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 4.0,
#   'Tarjetas Rojas': 2.0,
#   'Goles Esperados': 1.3,
#   'Asistencias Esperadas': 0.1,
#   'Valor de mercado': 300000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cc6'),
#   'Jugador': 'Abdoulaye Touré',
#   'País': 'GUI',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Genoa',
#   'Edad': 27,
#   'Nacimiento': 1994.0,
#   'PJ': 8.0,
#   'Titular': 6.0,
#   'Mín': 430.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.1,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 1200000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cc7'),
#   'Jugador': 'Abdul Mumin',
#   'País': 'GHA',
#   'Posc': 'Defensa',
#   'Equipo': 'Rayo Vallecano',
#   'Edad': 25,
#   'Nacimiento': 1998.0,
#   'PJ': 11.0,
#   'Titular': 7.0,
#   'Mín': 678.0,
#   'Gls.': 0.5,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.5,
#   'Tarjetas Amarillas': 1.5,
#   'Tarjetas Rojas': 0.5,
#   'Goles Esperados': 0.2,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 1500000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cc8'),
#   'Jugador': 'Abdón Prats',
#   'País': 'ESP',
#   'Posc': 'Delantero',
#   'Equipo': 'Mallorca',
#   'Edad': 30,
#   'Nacimiento': 1992.0,
#   'PJ': 20.0,
#   'Titular': 3.75,
#   'Mín': 459.5,
#   'Gls.': 2.25,
#   'Asistencias': 0.5,
#   'Goles+Asistencias': 2.75,
#   'Tarjetas Amarillas': 1.25,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 1.3,
#   'Asistencias Esperadas': 0.7749999999999999,
#   'Valor de mercado': 2000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cca'),
#   'Jugador': 'Abner',
#   'País': 'BRA',
#   'Posc': 'Defensa',
#   'Equipo': 'Betis',
#   'Edad': 23,
#   'Nacimiento': 2000.0,
#   'PJ': 11.0,
#   'Titular': 6.0,
#   'Mín': 564.5,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 2.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.9,
#   'Asistencias Esperadas': 0.25,
#   'Valor de mercado': 7000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026ccb'),
#   'Jugador': 'Aboubakar Kamara',
#   'País': 'MTN',
#   'Posc': 'Delantero',
#   'Equipo': 'Fulham',
#   'Edad': 25,
#   'Nacimiento': 1995.0,
#   'PJ': 11.0,
#   'Titular': 2.0,
#   'Mín': 315.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 1.0,
#   'Goles Esperados': 0.5,
#   'Asistencias Esperadas': 0.3,
#   'Valor de mercado': 2500000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026ccd'),
#   'Jugador': 'Adalberto Peñaranda',
#   'País': 'VEN',
#   'Posc': 'Delantero',
#   'Equipo': 'Málaga',
#   'Edad': 20,
#   'Nacimiento': 1997.0,
#   'PJ': 13.0,
#   'Titular': 11.0,
#   'Mín': 802.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 3.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.7,
#   'Asistencias Esperadas': 0.4,
#   'Valor de mercado': 400000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026ccf'),
#   'Jugador': 'Adam Forshaw',
#   'País': 'ENG',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Leeds United',
#   'Edad': 30,
#   'Nacimiento': 1991.0,
#   'PJ': 17.0,
#   'Titular': 11.0,
#   'Mín': 1004.5,
#   'Gls.': 0.0,
#   'Asistencias': 0.5,
#   'Goles+Asistencias': 0.5,
#   'Tarjetas Amarillas': 2.5,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.25,
#   'Asistencias Esperadas': 0.95,
#   'Valor de mercado': 1200000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cd0'),
#   'Jugador': 'Adam Idah',
#   'País': 'IRL',
#   'Posc': 'Delantero',
#   'Equipo': 'Norwich City',
#   'Edad': 20,
#   'Nacimiento': 2001.0,
#   'PJ': 14.5,
#   'Titular': 3.5,
#   'Mín': 426.5,
#   'Gls.': 0.5,
#   'Asistencias': 0.5,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 1.65,
#   'Asistencias Esperadas': 0.3,
#   'Valor de mercado': 2000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cd1'),
#   'Jugador': 'Adam Lallana',
#   'País': 'ENG',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Brighton',
#   'Edad': 35,
#   'Nacimiento': 1988.0,
#   'PJ': 18.6,
#   'Titular': 10.8,
#   'Mín': 913.4,
#   'Gls.': 0.8,
#   'Asistencias': 0.8,
#   'Goles+Asistencias': 1.6,
#   'Tarjetas Amarillas': 1.2,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.8800000000000001,
#   'Asistencias Esperadas': 1.12,
#   'Valor de mercado': 1200000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cd2'),
#   'Jugador': 'Adam Marušić',
#   'País': 'MNE',
#   'Posc': 'Defensa',
#   'Equipo': 'Lazio',
#   'Edad': 31,
#   'Nacimiento': 1992.0,
#   'PJ': 26.0,
#   'Titular': 23.4,
#   'Mín': 2096.4,
#   'Gls.': 1.0,
#   'Asistencias': 1.2,
#   'Goles+Asistencias': 2.2,
#   'Tarjetas Amarillas': 4.2,
#   'Tarjetas Rojas': 0.4,
#   'Goles Esperados': 1.0,
#   'Asistencias Esperadas': 0.9,
#   'Valor de mercado': 8000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cd3'),
#   'Jugador': 'Adam Masina',
#   'País': 'MAR',
#   'Posc': 'Defensa',
#   'Equipo': 'Watford',
#   'Edad': 28,
#   'Nacimiento': 1994.0,
#   'PJ': 18.33333333333333,
#   'Titular': 13.666666666666666,
#   'Mín': 1229.0,
#   'Gls.': 1.0,
#   'Asistencias': 0.3333333333333333,
#   'Goles+Asistencias': 1.3333333333333333,
#   'Tarjetas Amarillas': 1.6666666666666667,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.4333333333333333,
#   'Asistencias Esperadas': 0.4999999999999999,
#   'Valor de mercado': 2500000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cd4'),
#   'Jugador': 'Adam Obert',
#   'País': 'SVK',
#   'Posc': 'Defensa',
#   'Equipo': 'Cagliari',
#   'Edad': 21,
#   'Nacimiento': 2002.0,
#   'PJ': 7.0,
#   'Titular': 3.5,
#   'Mín': 326.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.5,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.25,
#   'Valor de mercado': 1800000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cd5'),
#   'Jugador': 'Adam Ounas',
#   'País': 'ALG',
#   'Posc': 'Delantero',
#   'Equipo': 'Napoli',
#   'Edad': 25,
#   'Nacimiento': 1996.0,
#   'PJ': 9.75,
#   'Titular': 4.75,
#   'Mín': 462.0,
#   'Gls.': 1.0,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 2.0,
#   'Tarjetas Amarillas': 0.5,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.975,
#   'Asistencias Esperadas': 1.15,
#   'Valor de mercado': 7000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cd6'),
#   'Jugador': 'Adam Smith',
#   'País': 'ENG',
#   'Posc': 'Defensa',
#   'Equipo': 'Bournemouth',
#   'Edad': 32,
#   'Nacimiento': 1991.0,
#   'PJ': 22.0,
#   'Titular': 20.0,
#   'Mín': 1736.6666666666667,
#   'Gls.': 0.0,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 6.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.4333333333333333,
#   'Asistencias Esperadas': 0.9333333333333336,
#   'Valor de mercado': 1200000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cd8'),
#   'Jugador': 'Adama Soumaoro',
#   'País': 'FRA',
#   'Posc': 'Defensa',
#   'Equipo': 'Bologna',
#   'Edad': 30,
#   'Nacimiento': 1992.0,
#   'PJ': 19.75,
#   'Titular': 18.5,
#   'Mín': 1631.25,
#   'Gls.': 0.5,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.5,
#   'Tarjetas Amarillas': 4.25,
#   'Tarjetas Rojas': 0.75,
#   'Goles Esperados': 0.7499999999999999,
#   'Asistencias Esperadas': 0.05,
#   'Valor de mercado': 3000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cdb'),
#   'Jugador': 'Adnan Januzaj',
#   'País': 'BEL',
#   'Posc': 'Delantero',
#   'Equipo': 'Real Sociedad',
#   'Edad': 28,
#   'Nacimiento': 1995.0,
#   'PJ': 19.428571428571427,
#   'Titular': 10.571428571428571,
#   'Mín': 960.5714285714286,
#   'Gls.': 2.0,
#   'Asistencias': 2.2857142857142856,
#   'Goles+Asistencias': 4.285714285714286,
#   'Tarjetas Amarillas': 2.142857142857143,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 2.814285714285714,
#   'Asistencias Esperadas': 2.628571428571429,
#   'Valor de mercado': 4000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cdc'),
#   'Jugador': 'Adolfo Gaich',
#   'País': 'ARG',
#   'Posc': 'Delantero',
#   'Equipo': 'Hellas Verona',
#   'Edad': 23,
#   'Nacimiento': 1999.0,
#   'PJ': 15.5,
#   'Titular': 8.5,
#   'Mín': 747.0,
#   'Gls.': 2.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 2.0,
#   'Tarjetas Amarillas': 1.5,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 2.65,
#   'Asistencias Esperadas': 0.4,
#   'Valor de mercado': 1800000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cdd'),
#   'Jugador': 'Adri Bosch',
#   'País': 'ESP',
#   'Posc': 'Defensa',
#   'Equipo': 'Granada',
#   'Edad': 22,
#   'Nacimiento': 2001.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 26.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 0.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cde'),
#   'Jugador': 'Adri Embarba',
#   'País': 'ESP',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Rayo Vallecano',
#   'Edad': 31,
#   'Nacimiento': 1992.0,
#   'PJ': 21.5,
#   'Titular': 16.166666666666668,
#   'Mín': 1339.3333333333333,
#   'Gls.': 1.8333333333333333,
#   'Asistencias': 2.5,
#   'Goles+Asistencias': 4.333333333333333,
#   'Tarjetas Amarillas': 3.333333333333333,
#   'Tarjetas Rojas': 0.3333333333333333,
#   'Goles Esperados': 2.9166666666666665,
#   'Asistencias Esperadas': 3.1333333333333333,
#   'Valor de mercado': 0.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cdf'),
#   'Jugador': 'Adrian Mariappa',
#   'País': 'JAM',
#   'Posc': 'Defensa',
#   'Equipo': 'Watford',
#   'Edad': 32,
#   'Nacimiento': 1986.0,
#   'PJ': 20.0,
#   'Titular': 15.0,
#   'Mín': 1513.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 6.0,
#   'Tarjetas Rojas': 1.0,
#   'Goles Esperados': 0.2,
#   'Asistencias Esperadas': 0.2,
#   'Valor de mercado': 100000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026ce0'),
#   'Jugador': 'Adrian Šemper',
#   'País': 'CRO',
#   'Posc': 'PO',
#   'Equipo': 'Genoa',
#   'Edad': 23,
#   'Nacimiento': 1998.0,
#   'PJ': 1.0,
#   'Titular': 1.0,
#   'Mín': 90.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 1200000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026ce2'),
#   'Jugador': 'Adrien Silva',
#   'País': 'POR',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Sampdoria',
#   'Edad': 32,
#   'Nacimiento': 1989.0,
#   'PJ': 20.5,
#   'Titular': 15.0,
#   'Mín': 1341.0,
#   'Gls.': 0.5,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 1.5,
#   'Tarjetas Amarillas': 5.5,
#   'Tarjetas Rojas': 1.0,
#   'Goles Esperados': 0.4,
#   'Asistencias Esperadas': 0.6000000000000001,
#   'Valor de mercado': 1000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026ce3'),
#   'Jugador': 'Adrien Tameze',
#   'País': 'CMR',
#   'Posc': 'Defensa',
#   'Equipo': 'Torino',
#   'Edad': 29,
#   'Nacimiento': 1994.0,
#   'PJ': 25.2,
#   'Titular': 20.0,
#   'Mín': 1780.8,
#   'Gls.': 1.0,
#   'Asistencias': 0.8,
#   'Goles+Asistencias': 1.8,
#   'Tarjetas Amarillas': 3.2,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.68,
#   'Asistencias Esperadas': 0.8999999999999998,
#   'Valor de mercado': 6000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026ce4'),
#   'Jugador': 'Adrià Altimira',
#   'País': 'ESP',
#   'Posc': 'Defensa',
#   'Equipo': 'Villarreal',
#   'Edad': 22,
#   'Nacimiento': 2001.0,
#   'PJ': 5.0,
#   'Titular': 4.0,
#   'Mín': 348.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.1,
#   'Valor de mercado': 1000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026ce5'),
#   'Jugador': 'Adrià Pedrosa',
#   'País': 'ESP',
#   'Posc': 'Defensa',
#   'Equipo': 'Espanyol',
#   'Edad': 25,
#   'Nacimiento': 1998.0,
#   'PJ': 16.2,
#   'Titular': 11.6,
#   'Mín': 1096.2,
#   'Gls.': 0.6,
#   'Asistencias': 0.6,
#   'Goles+Asistencias': 1.2,
#   'Tarjetas Amarillas': 2.6,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.62,
#   'Asistencias Esperadas': 0.86,
#   'Valor de mercado': 5000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026ce6'),
#   'Jugador': 'Adrián Butzke',
#   'País': 'ESP',
#   'Posc': 'Delantero',
#   'Equipo': 'Granada',
#   'Edad': 22,
#   'Nacimiento': 1999.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 1.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 400000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026ce7'),
#   'Jugador': 'Adrián Diéguez',
#   'País': 'ESP',
#   'Posc': 'Defensa',
#   'Equipo': 'Alavés',
#   'Edad': 22,
#   'Nacimiento': 1996.0,
#   'PJ': 7.5,
#   'Titular': 7.0,
#   'Mín': 592.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 4.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.1,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 600000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026ce8'),
#   'Jugador': 'Adrián Guerrero',
#   'País': 'ESP',
#   'Posc': 'Defensa',
#   'Equipo': 'Valencia',
#   'Edad': 21,
#   'Nacimiento': 1998.0,
#   'PJ': 2.0,
#   'Titular': 1.0,
#   'Mín': 126.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 2000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026ce9'),
#   'Jugador': 'Adrián Marín',
#   'País': 'ESP',
#   'Posc': 'Defensa',
#   'Equipo': 'Villarreal',
#   'Edad': 23,
#   'Nacimiento': 1997.0,
#   'PJ': 7.0,
#   'Titular': 3.4,
#   'Mín': 347.4,
#   'Gls.': 0.0,
#   'Asistencias': 0.2,
#   'Goles+Asistencias': 0.2,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.24,
#   'Asistencias Esperadas': 0.1,
#   'Valor de mercado': 1500000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cea'),
#   'Jugador': 'Adrián Ramos',
#   'País': 'COL',
#   'Posc': 'Delantero',
#   'Equipo': 'Granada',
#   'Edad': 33,
#   'Nacimiento': 1986.0,
#   'PJ': 7.0,
#   'Titular': 2.0,
#   'Mín': 226.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.4,
#   'Asistencias Esperadas': 0.7,
#   'Valor de mercado': 300000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026ceb'),
#   'Jugador': 'Adu Ares',
#   'País': 'ESP',
#   'Posc': 'Delantero',
#   'Equipo': 'Athletic Club',
#   'Edad': 22,
#   'Nacimiento': 2001.0,
#   'PJ': 5.0,
#   'Titular': 0.0,
#   'Mín': 54.5,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.5,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.05,
#   'Asistencias Esperadas': 0.1,
#   'Valor de mercado': 500000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cec'),
#   'Jugador': 'Ager Aketxe',
#   'País': 'ESP',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Athletic Club',
#   'Edad': 23,
#   'Nacimiento': 1993.0,
#   'PJ': 3.0,
#   'Titular': 0.0,
#   'Mín': 37.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.1,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 1000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026ced'),
#   'Jugador': 'Agustín Marchesín',
#   'País': 'ARG',
#   'Posc': 'PO',
#   'Equipo': 'Celta Vigo',
#   'Edad': 34,
#   'Nacimiento': 1988.0,
#   'PJ': 19.0,
#   'Titular': 19.0,
#   'Mín': 1710.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 2.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 1500000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cee'),
#   'Jugador': 'Agustín Martegani',
#   'País': 'ARG',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Salernitana',
#   'Edad': 23,
#   'Nacimiento': 2000.0,
#   'PJ': 9.0,
#   'Titular': 3.0,
#   'Mín': 400.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.2,
#   'Asistencias Esperadas': 0.4,
#   'Valor de mercado': 2000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cef'),
#   'Jugador': 'Agustín Álvarez Martínez',
#   'País': 'URU',
#   'Posc': 'Delantero',
#   'Equipo': 'Sassuolo',
#   'Edad': 21,
#   'Nacimiento': 2001.0,
#   'PJ': 22.0,
#   'Titular': 1.0,
#   'Mín': 368.0,
#   'Gls.': 1.0,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 2.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 1.5,
#   'Asistencias Esperadas': 0.4,
#   'Valor de mercado': 8000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cf0'),
#   'Jugador': 'Ahmad Benali',
#   'País': 'LBY',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Crotone',
#   'Edad': 28,
#   'Nacimiento': 1992.0,
#   'PJ': 18.0,
#   'Titular': 15.0,
#   'Mín': 1214.0,
#   'Gls.': 0.0,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 2.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.6,
#   'Asistencias Esperadas': 1.2,
#   'Valor de mercado': 900000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cf1'),
#   'Jugador': 'Ahmed Elmohamady',
#   'País': 'EGY',
#   'Posc': 'Defensa',
#   'Equipo': 'Aston Villa',
#   'Edad': 32,
#   'Nacimiento': 1987.0,
#   'PJ': 16.0,
#   'Titular': 9.5,
#   'Mín': 935.0,
#   'Gls.': 0.5,
#   'Asistencias': 0.5,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 1.5,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.3,
#   'Asistencias Esperadas': 1.9,
#   'Valor de mercado': 0.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cf2'),
#   'Jugador': 'Ahmed Hegazi',
#   'País': 'EGY',
#   'Posc': 'Defensa',
#   'Equipo': 'West Brom',
#   'Edad': 29,
#   'Nacimiento': 1991.0,
#   'PJ': 1.0,
#   'Titular': 1.0,
#   'Mín': 90.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 2500000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cf3'),
#   'Jugador': 'Ahmed Touba',
#   'País': 'ALG',
#   'Posc': 'Defensa',
#   'Equipo': 'Lecce',
#   'Edad': 25,
#   'Nacimiento': 1998.0,
#   'PJ': 3.0,
#   'Titular': 1.0,
#   'Mín': 114.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 2800000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cf4'),
#   'Jugador': 'Aihen Muñoz',
#   'País': 'ESP',
#   'Posc': 'Defensa',
#   'Equipo': 'Real Sociedad',
#   'Edad': 26,
#   'Nacimiento': 1997.0,
#   'PJ': 16.5,
#   'Titular': 13.5,
#   'Mín': 1211.5,
#   'Gls.': 0.0,
#   'Asistencias': 0.5,
#   'Goles+Asistencias': 0.5,
#   'Tarjetas Amarillas': 2.5,
#   'Tarjetas Rojas': 0.1666666666666666,
#   'Goles Esperados': 0.1333333333333333,
#   'Asistencias Esperadas': 0.5166666666666667,
#   'Valor de mercado': 6000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cf6'),
#   'Jugador': 'Aimar Sher',
#   'País': 'SWE',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Spezia',
#   'Edad': 18,
#   'Nacimiento': 2002.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 45.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 750000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cf7'),
#   'Jugador': 'Ainsley Maitland-Niles',
#   'País': 'ENG',
#   'Posc': 'Defensa',
#   'Equipo': 'Southampton',
#   'Edad': 24,
#   'Nacimiento': 1997.0,
#   'PJ': 14.0,
#   'Titular': 9.333333333333334,
#   'Mín': 878.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.3333333333333333,
#   'Goles+Asistencias': 0.3333333333333333,
#   'Tarjetas Amarillas': 1.8333333333333333,
#   'Tarjetas Rojas': 0.1666666666666666,
#   'Goles Esperados': 0.25,
#   'Asistencias Esperadas': 0.65,
#   'Valor de mercado': 6000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cf8'),
#   'Jugador': 'Aitor Fernández',
#   'País': 'ESP',
#   'Posc': 'PO',
#   'Equipo': 'Levante',
#   'Edad': 32,
#   'Nacimiento': 1991.0,
#   'PJ': 19.83333333333333,
#   'Titular': 19.666666666666668,
#   'Mín': 1771.1666666666667,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.1666666666666666,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0666666666666666,
#   'Valor de mercado': 3000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cf9'),
#   'Jugador': 'Aitor Paredes',
#   'País': 'ESP',
#   'Posc': 'Defensa',
#   'Equipo': 'Athletic Club',
#   'Edad': 23,
#   'Nacimiento': 2000.0,
#   'PJ': 15.0,
#   'Titular': 10.5,
#   'Mín': 962.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 3.5,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.45,
#   'Asistencias Esperadas': 0.25,
#   'Valor de mercado': 8000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cfa'),
#   'Jugador': 'Aitor Ruibal',
#   'País': 'ESP',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Betis',
#   'Edad': 27,
#   'Nacimiento': 1996.0,
#   'PJ': 17.666666666666668,
#   'Titular': 10.166666666666666,
#   'Mín': 895.8333333333334,
#   'Gls.': 0.3333333333333333,
#   'Asistencias': 0.5,
#   'Goles+Asistencias': 0.8333333333333334,
#   'Tarjetas Amarillas': 3.0,
#   'Tarjetas Rojas': 0.1666666666666666,
#   'Goles Esperados': 0.9499999999999998,
#   'Asistencias Esperadas': 1.3333333333333333,
#   'Valor de mercado': 5000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cfb'),
#   'Jugador': 'Ajdin Hrustic',
#   'País': 'AUS',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Hellas Verona',
#   'Edad': 26,
#   'Nacimiento': 1996.0,
#   'PJ': 6.0,
#   'Titular': 3.0,
#   'Mín': 226.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.3,
#   'Asistencias Esperadas': 0.6,
#   'Valor de mercado': 900000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cfc'),
#   'Jugador': 'Akin Famewo',
#   'País': 'ENG',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Norwich City',
#   'Edad': 20,
#   'Nacimiento': 1998.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 1.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 300000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cfd'),
#   'Jugador': 'Alan Empereur',
#   'País': 'BRA',
#   'Posc': 'Defensa',
#   'Equipo': 'Hellas Verona',
#   'Edad': 26,
#   'Nacimiento': 1994.0,
#   'PJ': 8.5,
#   'Titular': 6.0,
#   'Mín': 537.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 2.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.1,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 750000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cfe'),
#   'Jugador': 'Alan Matturro',
#   'País': 'URU',
#   'Posc': 'Defensa',
#   'Equipo': 'Genoa',
#   'Edad': 19,
#   'Nacimiento': 2004.0,
#   'PJ': 3.0,
#   'Titular': 1.0,
#   'Mín': 84.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 2500000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026cff'),
#   'Jugador': 'Alassane Sidibe',
#   'País': 'CIV',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Atalanta',
#   'Edad': 19,
#   'Nacimiento': 2002.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 6.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 750000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d02'),
#   'Jugador': 'Alberto Basso',
#   'País': 'ITA',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Cremonese',
#   'Edad': 18,
#   'Nacimiento': 2004.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 16.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 100000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d03'),
#   'Jugador': 'Alberto Cerri',
#   'País': 'ITA',
#   'Posc': 'Delantero',
#   'Equipo': 'Cagliari',
#   'Edad': 24,
#   'Nacimiento': 1996.0,
#   'PJ': 14.0,
#   'Titular': 3.0,
#   'Mín': 344.3333333333333,
#   'Gls.': 1.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 1.6333333333333335,
#   'Asistencias Esperadas': 0.4666666666666666,
#   'Valor de mercado': 2000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d04'),
#   'Jugador': 'Alberto Del Moral',
#   'País': 'ESP',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Villarreal',
#   'Edad': 22,
#   'Nacimiento': 2000.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 5.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 1000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d05'),
#   'Jugador': 'Alberto Dossena',
#   'País': 'ITA',
#   'Posc': 'Defensa',
#   'Equipo': 'Cagliari',
#   'Edad': 25,
#   'Nacimiento': 1998.0,
#   'PJ': 13.0,
#   'Titular': 12.0,
#   'Mín': 1086.0,
#   'Gls.': 2.0,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 3.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 1.1,
#   'Asistencias Esperadas': 0.6,
#   'Valor de mercado': 2000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d06'),
#   'Jugador': 'Alberto García',
#   'País': 'ESP',
#   'Posc': 'PO',
#   'Equipo': 'Rayo Vallecano',
#   'Edad': 33,
#   'Nacimiento': 1985.0,
#   'PJ': 17.0,
#   'Titular': 17.0,
#   'Mín': 1530.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 3000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d07'),
#   'Jugador': 'Alberto Grassi',
#   'País': 'ITA',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Empoli',
#   'Edad': 28,
#   'Nacimiento': 1995.0,
#   'PJ': 21.0,
#   'Titular': 13.2,
#   'Mín': 1176.2,
#   'Gls.': 0.2,
#   'Asistencias': 0.6,
#   'Goles+Asistencias': 0.8,
#   'Tarjetas Amarillas': 4.2,
#   'Tarjetas Rojas': 0.2,
#   'Goles Esperados': 0.54,
#   'Asistencias Esperadas': 0.74,
#   'Valor de mercado': 2000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d08'),
#   'Jugador': 'Alberto López',
#   'País': 'ESP',
#   'Posc': 'Defensa',
#   'Equipo': 'Málaga',
#   'Edad': 22,
#   'Nacimiento': 1995.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 45.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 7000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d09'),
#   'Jugador': 'Alberto Moleiro',
#   'País': 'ESP',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Las Palmas',
#   'Edad': 20,
#   'Nacimiento': 2003.0,
#   'PJ': 5.0,
#   'Titular': 2.0,
#   'Mín': 233.0,
#   'Gls.': 1.0,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 2.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.3,
#   'Asistencias Esperadas': 0.1,
#   'Valor de mercado': 5000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d0a'),
#   'Jugador': 'Alberto Moreno',
#   'País': 'ESP',
#   'Posc': 'Defensa',
#   'Equipo': 'Villarreal',
#   'Edad': 31,
#   'Nacimiento': 1992.0,
#   'PJ': 16.2,
#   'Titular': 10.0,
#   'Mín': 926.2,
#   'Gls.': 0.6,
#   'Asistencias': 0.8,
#   'Goles+Asistencias': 1.4,
#   'Tarjetas Amarillas': 3.6,
#   'Tarjetas Rojas': 0.2,
#   'Goles Esperados': 1.04,
#   'Asistencias Esperadas': 0.8399999999999999,
#   'Valor de mercado': 2000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d0b'),
#   'Jugador': 'Alberto Paleari',
#   'País': 'ITA',
#   'Posc': 'PO',
#   'Equipo': 'Genoa',
#   'Edad': 27,
#   'Nacimiento': 1992.0,
#   'PJ': 3.0,
#   'Titular': 2.0,
#   'Mín': 206.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 700000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d0c'),
#   'Jugador': 'Alberto Paloschi',
#   'País': 'ITA',
#   'Posc': 'Delantero',
#   'Equipo': 'SPAL',
#   'Edad': 29,
#   'Nacimiento': 1990.0,
#   'PJ': 8.5,
#   'Titular': 3.0,
#   'Mín': 321.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.9,
#   'Asistencias Esperadas': 0.25,
#   'Valor de mercado': 500000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d0d'),
#   'Jugador': 'Alberto Perea',
#   'País': 'ESP',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Cádiz',
#   'Edad': 32,
#   'Nacimiento': 1990.0,
#   'PJ': 12.0,
#   'Titular': 6.25,
#   'Mín': 593.25,
#   'Gls.': 0.5,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 1.5,
#   'Tarjetas Amarillas': 0.5,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.675,
#   'Asistencias Esperadas': 0.8,
#   'Valor de mercado': 1000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d0e'),
#   'Jugador': 'Alberto Soro',
#   'País': 'ESP',
#   'Posc': 'Delantero',
#   'Equipo': 'Granada',
#   'Edad': 24,
#   'Nacimiento': 1999.0,
#   'PJ': 10.666666666666666,
#   'Titular': 3.333333333333333,
#   'Mín': 326.3333333333333,
#   'Gls.': 0.3333333333333333,
#   'Asistencias': 0.6666666666666666,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 0.3333333333333333,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.5,
#   'Asistencias Esperadas': 0.2666666666666666,
#   'Valor de mercado': 1500000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d0f'),
#   'Jugador': 'Albian Ajeti',
#   'País': 'SUI',
#   'Posc': 'Delantero',
#   'Equipo': 'West Ham',
#   'Edad': 22,
#   'Nacimiento': 1997.0,
#   'PJ': 9.0,
#   'Titular': 0.0,
#   'Mín': 139.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.2,
#   'Asistencias Esperadas': 0.1,
#   'Valor de mercado': 1500000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d10'),
#   'Jugador': 'Albin Ekdal',
#   'País': 'SWE',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Spezia',
#   'Edad': 33,
#   'Nacimiento': 1989.0,
#   'PJ': 30.25,
#   'Titular': 22.5,
#   'Mín': 2013.75,
#   'Gls.': 0.75,
#   'Asistencias': 1.25,
#   'Goles+Asistencias': 2.0,
#   'Tarjetas Amarillas': 8.5,
#   'Tarjetas Rojas': 0.5,
#   'Goles Esperados': 1.55,
#   'Asistencias Esperadas': 1.0,
#   'Valor de mercado': 800000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d11'),
#   'Jugador': 'Aleix Febas',
#   'País': 'ESP',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Mallorca',
#   'Edad': 25,
#   'Nacimiento': 1996.0,
#   'PJ': 16.5,
#   'Titular': 11.5,
#   'Mín': 903.5,
#   'Gls.': 0.0,
#   'Asistencias': 1.5,
#   'Goles+Asistencias': 1.5,
#   'Tarjetas Amarillas': 2.5,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.2,
#   'Asistencias Esperadas': 0.9,
#   'Valor de mercado': 1500000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d13'),
#   'Jugador': 'Aleix Garrido',
#   'País': 'ESP',
#   'Posc': 'Delantero',
#   'Equipo': 'Barcelona',
#   'Edad': 18,
#   'Nacimiento': 2004.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 7.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 300000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d14'),
#   'Jugador': 'Aleix Vidal',
#   'País': 'ESP',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Barcelona',
#   'Edad': 32,
#   'Nacimiento': 1989.0,
#   'PJ': 20.5,
#   'Titular': 11.833333333333334,
#   'Mín': 1112.3333333333333,
#   'Gls.': 0.8333333333333334,
#   'Asistencias': 1.5,
#   'Goles+Asistencias': 2.333333333333333,
#   'Tarjetas Amarillas': 5.166666666666667,
#   'Tarjetas Rojas': 0.1666666666666666,
#   'Goles Esperados': 0.8833333333333333,
#   'Asistencias Esperadas': 2.016666666666667,
#   'Valor de mercado': 1000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d15'),
#   'Jugador': 'Alejandro Arribas',
#   'País': 'ESP',
#   'Posc': 'Defensa',
#   'Equipo': 'La Coruña',
#   'Edad': 28,
#   'Nacimiento': 1989.0,
#   'PJ': 3.0,
#   'Titular': 3.0,
#   'Mín': 270.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.2,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 350000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d16'),
#   'Jugador': 'Alejandro Asensio',
#   'País': 'ESP',
#   'Posc': 'Delantero',
#   'Equipo': 'Rayo Vallecano',
#   'Edad': 20,
#   'Nacimiento': 2000.0,
#   'PJ': 2.0,
#   'Titular': 0.0,
#   'Mín': 12.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 25000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d18'),
#   'Jugador': 'Alejandro Blanco',
#   'País': 'ESP',
#   'Posc': 'Delantero',
#   'Equipo': 'Alavés',
#   'Edad': 21,
#   'Nacimiento': 1998.0,
#   'PJ': 7.5,
#   'Titular': 3.0,
#   'Mín': 298.0,
#   'Gls.': 0.5,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.5,
#   'Tarjetas Amarillas': 0.5,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.25,
#   'Asistencias Esperadas': 0.25,
#   'Valor de mercado': 600000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d19'),
#   'Jugador': 'Alejandro Blesa',
#   'País': 'ESP',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Levante',
#   'Edad': 18,
#   'Nacimiento': 2002.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 6.5,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 300000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d1b'),
#   'Jugador': 'Alejandro Pozo Pozo',
#   'País': 'ESP',
#   'Posc': 'Defensa',
#   'Equipo': 'Mallorca',
#   'Edad': 24,
#   'Nacimiento': 1999.0,
#   'PJ': 18.2,
#   'Titular': 12.8,
#   'Mín': 1201.6,
#   'Gls.': 0.2,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 1.2,
#   'Tarjetas Amarillas': 1.2,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.24,
#   'Asistencias Esperadas': 1.34,
#   'Valor de mercado': 3000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d1c'),
#   'Jugador': 'Alejandro Primo',
#   'País': 'ESP',
#   'Posc': 'PO',
#   'Equipo': 'Levante',
#   'Edad': 17,
#   'Nacimiento': 2004.0,
#   'PJ': 1.0,
#   'Titular': 1.0,
#   'Mín': 90.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 100000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d1d'),
#   'Jugador': 'Alejandro Revuelta Montero',
#   'País': 'ESP',
#   'Posc': 'Defensa',
#   'Equipo': 'Getafe',
#   'Edad': 22,
#   'Nacimiento': 2000.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 1.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 25000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d1f'),
#   'Jugador': 'Aleksa Terzić',
#   'País': 'SRB',
#   'Posc': 'Defensa',
#   'Equipo': 'Fiorentina',
#   'Edad': 22,
#   'Nacimiento': 1999.0,
#   'PJ': 12.666666666666666,
#   'Titular': 3.0,
#   'Mín': 405.6666666666667,
#   'Gls.': 0.3333333333333333,
#   'Asistencias': 0.6666666666666666,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.1333333333333333,
#   'Asistencias Esperadas': 0.7666666666666666,
#   'Valor de mercado': 4000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d20'),
#   'Jugador': 'Aleksandar Jovanović',
#   'País': 'SRB',
#   'Posc': 'PO',
#   'Equipo': 'Huesca',
#   'Edad': 25,
#   'Nacimiento': 1992.0,
#   'PJ': 12.0,
#   'Titular': 12.0,
#   'Mín': 1080.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 800000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d21'),
#   'Jugador': 'Aleksandar Katai',
#   'País': 'SRB',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Alavés',
#   'Edad': 26,
#   'Nacimiento': 1991.0,
#   'PJ': 3.0,
#   'Titular': 0.0,
#   'Mín': 55.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.1,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 4500000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d23'),
#   'Jugador': 'Aleksandar Sedlar',
#   'País': 'SRB',
#   'Posc': 'Defensa',
#   'Equipo': 'Mallorca',
#   'Edad': 31,
#   'Nacimiento': 1991.0,
#   'PJ': 11.0,
#   'Titular': 7.666666666666667,
#   'Mín': 721.3333333333334,
#   'Gls.': 0.3333333333333333,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.3333333333333333,
#   'Tarjetas Amarillas': 3.333333333333333,
#   'Tarjetas Rojas': 0.6666666666666666,
#   'Goles Esperados': 0.1333333333333333,
#   'Asistencias Esperadas': 0.0666666666666666,
#   'Valor de mercado': 500000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d24'),
#   'Jugador': 'Aleksandar Trajkovski',
#   'País': 'MKD',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Mallorca',
#   'Edad': 26,
#   'Nacimiento': 1992.0,
#   'PJ': 14.0,
#   'Titular': 1.0,
#   'Mín': 330.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.5,
#   'Asistencias Esperadas': 1.2,
#   'Valor de mercado': 450000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d25'),
#   'Jugador': 'Aleksander Buksa',
#   'País': 'POL',
#   'Posc': 'Delantero',
#   'Equipo': 'Genoa',
#   'Edad': 18,
#   'Nacimiento': 2003.0,
#   'PJ': 4.0,
#   'Titular': 0.0,
#   'Mín': 63.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 700000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d26'),
#   'Jugador': 'Aleksandr Kokorin',
#   'País': 'RUS',
#   'Posc': 'Delantero',
#   'Equipo': 'Fiorentina',
#   'Edad': 30,
#   'Nacimiento': 1991.0,
#   'PJ': 5.0,
#   'Titular': 0.0,
#   'Mín': 74.5,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 1000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d27'),
#   'Jugador': 'Aleksei Miranchuk',
#   'País': 'RUS',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Atalanta',
#   'Edad': 28,
#   'Nacimiento': 1995.0,
#   'PJ': 19.25,
#   'Titular': 9.0,
#   'Mín': 925.0,
#   'Gls.': 2.5,
#   'Asistencias': 3.0,
#   'Goles+Asistencias': 5.5,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 1.375,
#   'Asistencias Esperadas': 2.225,
#   'Valor de mercado': 9000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d28'),
#   'Jugador': 'Alen Halilović',
#   'País': 'CRO',
#   'Posc': 'Delantero',
#   'Equipo': 'Las Palmas',
#   'Edad': 21,
#   'Nacimiento': 1996.0,
#   'PJ': 20.0,
#   'Titular': 16.0,
#   'Mín': 1304.0,
#   'Gls.': 2.0,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 3.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 1.0,
#   'Goles Esperados': 1.6,
#   'Asistencias Esperadas': 1.8,
#   'Valor de mercado': 1000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d2a'),
#   'Jugador': 'Alessandro Berardi',
#   'País': 'ITA',
#   'Posc': 'PO',
#   'Equipo': 'Hellas Verona',
#   'Edad': 30,
#   'Nacimiento': 1991.0,
#   'PJ': 1.0,
#   'Titular': 0.5,
#   'Mín': 59.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 50000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d2b'),
#   'Jugador': 'Alessandro Bianco',
#   'País': 'ITA',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Fiorentina',
#   'Edad': 19,
#   'Nacimiento': 2002.0,
#   'PJ': 7.0,
#   'Titular': 2.0,
#   'Mín': 153.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.1,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 1200000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d2d'),
#   'Jugador': 'Alessandro Cortinovis',
#   'País': 'ITA',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Hellas Verona',
#   'Edad': 21,
#   'Nacimiento': 2001.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 6.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 700000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d2e'),
#   'Jugador': 'Alessandro Deiola',
#   'País': 'ITA',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Cagliari',
#   'Edad': 28,
#   'Nacimiento': 1995.0,
#   'PJ': 12.833333333333334,
#   'Titular': 8.666666666666666,
#   'Mín': 696.5,
#   'Gls.': 0.8333333333333334,
#   'Asistencias': 0.3333333333333333,
#   'Goles+Asistencias': 1.1666666666666667,
#   'Tarjetas Amarillas': 2.1666666666666665,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.7166666666666668,
#   'Asistencias Esperadas': 0.5,
#   'Valor de mercado': 1800000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d2f'),
#   'Jugador': 'Alessandro Di Pardo',
#   'País': 'ITA',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Cagliari',
#   'Edad': 24,
#   'Nacimiento': 1999.0,
#   'PJ': 5.0,
#   'Titular': 0.0,
#   'Mín': 93.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.05,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 900000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d30'),
#   'Jugador': 'Alessandro Florenzi',
#   'País': 'ITA',
#   'Posc': 'Defensa',
#   'Equipo': 'Valencia',
#   'Edad': 32,
#   'Nacimiento': 1991.0,
#   'PJ': 13.4,
#   'Titular': 8.0,
#   'Mín': 715.2,
#   'Gls.': 0.4,
#   'Asistencias': 0.2,
#   'Goles+Asistencias': 0.6,
#   'Tarjetas Amarillas': 2.4,
#   'Tarjetas Rojas': 0.2,
#   'Goles Esperados': 0.5599999999999999,
#   'Asistencias Esperadas': 0.8800000000000001,
#   'Valor de mercado': 2000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d31'),
#   'Jugador': 'Alessandro Murgia',
#   'País': 'ITA',
#   'Posc': 'Centrocampista',
#   'Equipo': 'SPAL',
#   'Edad': 22,
#   'Nacimiento': 1996.0,
#   'PJ': 25.0,
#   'Titular': 19.0,
#   'Mín': 1750.0,
#   'Gls.': 0.0,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 3.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 2.4,
#   'Asistencias Esperadas': 2.0,
#   'Valor de mercado': 450000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d32'),
#   'Jugador': 'Alessandro Russo',
#   'País': 'ITA',
#   'Posc': 'PO',
#   'Equipo': 'Sassuolo',
#   'Edad': 21,
#   'Nacimiento': 2002.0,
#   'PJ': 1.0,
#   'Titular': 0.5,
#   'Mín': 59.5,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 350000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d33'),
#   'Jugador': 'Alessandro Semprini',
#   'País': 'ITA',
#   'Posc': 'Defensa',
#   'Equipo': 'Brescia',
#   'Edad': 21,
#   'Nacimiento': 1998.0,
#   'PJ': 12.0,
#   'Titular': 6.0,
#   'Mín': 629.0,
#   'Gls.': 1.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 2.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.9,
#   'Asistencias Esperadas': 0.2,
#   'Valor de mercado': 125000.0},
#  {'_id': ObjectId('656dc7c4de86b9b413026d34'),
#   'Jugador': 'Alessandro Sorrentino',
#   'País': 'ITA',
#   'Posc': 'PO',
#   'Equipo': 'Monza',
#   'Edad': 21,
#   'Nacimiento': 2002.0,
#   'PJ': 1.0,
# ...
#   'Mín': 2472.0,
#   'Gls.': 3.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 3.0,
#   'Tarjetas Amarillas': 2.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 6.4,
#   'Asistencias Esperadas': 2.7,
#   'Valor de mercado': 2500000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271b5'),
#   'Jugador': 'Ivan Perišić',
#   'País': 'CRO',
#   'Posc': 'Delantero',
#   'Equipo': 'Tottenham',
#   'Edad': 34,
#   'Nacimiento': 1989.0,
#   'PJ': 26.5,
#   'Titular': 19.5,
#   'Mín': 1706.75,
#   'Gls.': 3.25,
#   'Asistencias': 4.5,
#   'Goles+Asistencias': 7.75,
#   'Tarjetas Amarillas': 3.75,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 3.05,
#   'Asistencias Esperadas': 4.8,
#   'Valor de mercado': 4000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271b7'),
#   'Jugador': 'Ivan Radovanović',
#   'País': 'SRB',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Salernitana',
#   'Edad': 33,
#   'Nacimiento': 1988.0,
#   'PJ': 19.0,
#   'Titular': 14.5,
#   'Mín': 1318.5,
#   'Gls.': 0.25,
#   'Asistencias': 0.5,
#   'Goles+Asistencias': 0.75,
#   'Tarjetas Amarillas': 3.5,
#   'Tarjetas Rojas': 0.25,
#   'Goles Esperados': 0.625,
#   'Asistencias Esperadas': 0.625,
#   'Valor de mercado': 400000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271b8'),
#   'Jugador': 'Ivan Rakitić',
#   'País': 'CRO',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Barcelona',
#   'Edad': 35,
#   'Nacimiento': 1988.0,
#   'PJ': 30.714285714285715,
#   'Titular': 22.714285714285715,
#   'Mín': 2038.4285714285716,
#   'Gls.': 2.2857142857142856,
#   'Asistencias': 3.571428571428572,
#   'Goles+Asistencias': 5.857142857142857,
#   'Tarjetas Amarillas': 4.571428571428571,
#   'Tarjetas Rojas': 0.2857142857142857,
#   'Goles Esperados': 2.7857142857142856,
#   'Asistencias Esperadas': 2.271428571428572,
#   'Valor de mercado': 4000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271ba'),
#   'Jugador': 'Ivan Šaponjić',
#   'País': 'SRB',
#   'Posc': 'Defensa',
#   'Equipo': 'Atlético Madrid',
#   'Edad': 22,
#   'Nacimiento': 1997.0,
#   'PJ': 5.5,
#   'Titular': 1.5,
#   'Mín': 197.0,
#   'Gls.': 0.5,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.5,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 1.25,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 650000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271bc'),
#   'Jugador': 'Ivo Grbić',
#   'País': 'CRO',
#   'Posc': 'PO',
#   'Equipo': 'Atlético Madrid',
#   'Edad': 26,
#   'Nacimiento': 1996.0,
#   'PJ': 12.0,
#   'Titular': 10.0,
#   'Mín': 922.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 3.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 3500000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271bd'),
#   'Jugador': 'Ivor Pandur',
#   'País': 'CRO',
#   'Posc': 'PO',
#   'Equipo': 'Hellas Verona',
#   'Edad': 21,
#   'Nacimiento': 2000.0,
#   'PJ': 3.5,
#   'Titular': 3.5,
#   'Mín': 301.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 2000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271be'),
#   'Jugador': 'Iván Alejo',
#   'País': 'ESP',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Eibar',
#   'Edad': 28,
#   'Nacimiento': 1995.0,
#   'PJ': 18.666666666666668,
#   'Titular': 9.5,
#   'Mín': 878.8333333333334,
#   'Gls.': 0.6666666666666666,
#   'Asistencias': 1.1666666666666667,
#   'Goles+Asistencias': 1.8333333333333333,
#   'Tarjetas Amarillas': 6.333333333333333,
#   'Tarjetas Rojas': 0.3333333333333333,
#   'Goles Esperados': 0.7000000000000001,
#   'Asistencias Esperadas': 1.3333333333333333,
#   'Valor de mercado': 1200000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271bf'),
#   'Jugador': 'Iván Balliu',
#   'País': 'ALB',
#   'Posc': 'Defensa',
#   'Equipo': 'Rayo Vallecano',
#   'Edad': 31,
#   'Nacimiento': 1992.0,
#   'PJ': 28.0,
#   'Titular': 28.0,
#   'Mín': 2486.333333333333,
#   'Gls.': 0.3333333333333333,
#   'Asistencias': 0.6666666666666666,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 5.666666666666667,
#   'Tarjetas Rojas': 0.3333333333333333,
#   'Goles Esperados': 0.4333333333333333,
#   'Asistencias Esperadas': 2.3,
#   'Valor de mercado': 4000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271c0'),
#   'Jugador': 'Iván Cuéllar',
#   'País': 'ESP',
#   'Posc': 'PO',
#   'Equipo': 'Leganés',
#   'Edad': 35,
#   'Nacimiento': 1984.0,
#   'PJ': 32.0,
#   'Titular': 32.0,
#   'Mín': 2878.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 4.333333333333333,
#   'Tarjetas Rojas': 0.3333333333333333,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0333333333333333,
#   'Valor de mercado': 100000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271c2'),
#   'Jugador': 'Iván López',
#   'País': 'ESP',
#   'Posc': 'Defensa',
#   'Equipo': 'Levante',
#   'Edad': 23,
#   'Nacimiento': 1993.0,
#   'PJ': 3.0,
#   'Titular': 3.0,
#   'Mín': 173.0,
#   'Gls.': 0.0,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.6,
#   'Valor de mercado': 2500000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271c3'),
#   'Jugador': 'Iván Marcone',
#   'País': 'ARG',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Elche',
#   'Edad': 31,
#   'Nacimiento': 1990.0,
#   'PJ': 26.5,
#   'Titular': 20.0,
#   'Mín': 1727.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 7.5,
#   'Tarjetas Rojas': 0.5,
#   'Goles Esperados': 0.1,
#   'Asistencias Esperadas': 0.3,
#   'Valor de mercado': 1200000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271c4'),
#   'Jugador': 'Iván Martín',
#   'País': 'ESP',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Alavés',
#   'Edad': 24,
#   'Nacimiento': 1999.0,
#   'PJ': 14.333333333333334,
#   'Titular': 10.666666666666666,
#   'Mín': 904.6666666666666,
#   'Gls.': 2.0,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 3.0,
#   'Tarjetas Amarillas': 1.6666666666666667,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 1.4666666666666668,
#   'Asistencias Esperadas': 0.9,
#   'Valor de mercado': 4000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271c5'),
#   'Jugador': 'Iván Rodríguez',
#   'País': 'ESP',
#   'Posc': 'Defensa',
#   'Equipo': 'Málaga',
#   'Edad': 21,
#   'Nacimiento': 1996.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 20.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 3500000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271c6'),
#   'Jugador': 'Iván Villar',
#   'País': 'ESP',
#   'Posc': 'PO',
#   'Equipo': 'Celta Vigo',
#   'Edad': 26,
#   'Nacimiento': 1997.0,
#   'PJ': 13.5,
#   'Titular': 12.75,
#   'Mín': 1151.25,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.25,
#   'Tarjetas Rojas': 0.25,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.025,
#   'Valor de mercado': 2000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271c7'),
#   'Jugador': 'Iñaki Peña',
#   'País': 'ESP',
#   'Posc': 'PO',
#   'Equipo': 'Barcelona',
#   'Edad': 24,
#   'Nacimiento': 1999.0,
#   'PJ': 1.5,
#   'Titular': 0.5,
#   'Mín': 81.5,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 4000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271c9'),
#   'Jugador': 'Iñigo Córdoba',
#   'País': 'ESP',
#   'Posc': 'Delantero',
#   'Equipo': 'Athletic Club',
#   'Edad': 23,
#   'Nacimiento': 1997.0,
#   'PJ': 17.4,
#   'Titular': 11.6,
#   'Mín': 906.6,
#   'Gls.': 0.4,
#   'Asistencias': 1.8,
#   'Goles+Asistencias': 2.2,
#   'Tarjetas Amarillas': 2.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.9399999999999998,
#   'Asistencias Esperadas': 1.1,
#   'Valor de mercado': 1800000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271ca'),
#   'Jugador': 'Iñigo Lekue',
#   'País': 'ESP',
#   'Posc': 'Defensa',
#   'Equipo': 'Athletic Club',
#   'Edad': 30,
#   'Nacimiento': 1993.0,
#   'PJ': 17.428571428571427,
#   'Titular': 11.0,
#   'Mín': 1065.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.7142857142857143,
#   'Goles+Asistencias': 0.7142857142857143,
#   'Tarjetas Amarillas': 1.5714285714285714,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.1571428571428571,
#   'Asistencias Esperadas': 0.8571428571428571,
#   'Valor de mercado': 3000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271cb'),
#   'Jugador': 'Iñigo Martínez',
#   'País': 'ESP',
#   'Posc': 'Defensa',
#   'Equipo': 'Athletic Club',
#   'Edad': 32,
#   'Nacimiento': 1991.0,
#   'PJ': 21.5,
#   'Titular': 21.125,
#   'Mín': 1888.5,
#   'Gls.': 0.875,
#   'Asistencias': 0.25,
#   'Goles+Asistencias': 1.125,
#   'Tarjetas Amarillas': 6.125,
#   'Tarjetas Rojas': 0.375,
#   'Goles Esperados': 1.2625,
#   'Asistencias Esperadas': 0.5125,
#   'Valor de mercado': 8000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271cc'),
#   'Jugador': 'Iñigo Ruiz de Galarreta',
#   'País': 'ESP',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Mallorca',
#   'Edad': 30,
#   'Nacimiento': 1993.0,
#   'PJ': 21.0,
#   'Titular': 18.666666666666668,
#   'Mín': 1581.0,
#   'Gls.': 0.3333333333333333,
#   'Asistencias': 0.3333333333333333,
#   'Goles+Asistencias': 0.6666666666666666,
#   'Tarjetas Amarillas': 6.666666666666667,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.3333333333333333,
#   'Asistencias Esperadas': 0.8666666666666667,
#   'Valor de mercado': 3000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271cd'),
#   'Jugador': 'Iñigo Vicente',
#   'País': 'ESP',
#   'Posc': 'Delantero',
#   'Equipo': 'Athletic Club',
#   'Edad': 22,
#   'Nacimiento': 1998.0,
#   'PJ': 3.0,
#   'Titular': 0.0,
#   'Mín': 52.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.2,
#   'Valor de mercado': 1800000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271ce'),
#   'Jugador': 'Jack Butland',
#   'País': 'ENG',
#   'Posc': 'PO',
#   'Equipo': 'Crystal Palace',
#   'Edad': 28,
#   'Nacimiento': 1993.0,
#   'PJ': 5.0,
#   'Titular': 4.5,
#   'Mín': 427.5,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 2000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271cf'),
#   'Jugador': 'Jack Colback',
#   'País': 'ENG',
#   'Posc': 'Centrocampista',
#   'Equipo': "Nott'ham Forest",
#   'Edad': 32,
#   'Nacimiento': 1989.0,
#   'PJ': 11.0,
#   'Titular': 4.0,
#   'Mín': 497.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.2,
#   'Valor de mercado': 600000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271d0'),
#   'Jugador': 'Jack Cork',
#   'País': 'ENG',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Burnley',
#   'Edad': 34,
#   'Nacimiento': 1989.0,
#   'PJ': 16.75,
#   'Titular': 16.25,
#   'Mín': 1412.5,
#   'Gls.': 0.25,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.25,
#   'Tarjetas Amarillas': 1.75,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.725,
#   'Asistencias Esperadas': 0.5,
#   'Valor de mercado': 1000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271d3'),
#   'Jugador': 'Jack Hendry',
#   'País': 'SCO',
#   'Posc': 'Defensa',
#   'Equipo': 'Cremonese',
#   'Edad': 27,
#   'Nacimiento': 1995.0,
#   'PJ': 4.0,
#   'Titular': 2.0,
#   'Mín': 220.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 3000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271d4'),
#   'Jugador': 'Jack Hinshelwood',
#   'País': 'ENG',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Brighton',
#   'Edad': 18,
#   'Nacimiento': 2005.0,
#   'PJ': 1.5,
#   'Titular': 0.5,
#   'Mín': 71.5,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.05,
#   'Valor de mercado': 1000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271d5'),
#   'Jugador': 'Jack Robinson',
#   'País': 'ENG',
#   'Posc': 'Defensa',
#   'Equipo': 'Sheffield Utd',
#   'Edad': 30,
#   'Nacimiento': 1993.0,
#   'PJ': 10.0,
#   'Titular': 9.0,
#   'Mín': 835.3333333333334,
#   'Gls.': 0.0,
#   'Asistencias': 0.6666666666666666,
#   'Goles+Asistencias': 0.6666666666666666,
#   'Tarjetas Amarillas': 2.333333333333333,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.3999999999999999,
#   'Asistencias Esperadas': 0.3666666666666666,
#   'Valor de mercado': 3000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271d6'),
#   'Jugador': 'Jack Rodwell',
#   'País': 'ENG',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Sheffield Utd',
#   'Edad': 28,
#   'Nacimiento': 1991.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 16.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 350000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271d7'),
#   'Jugador': 'Jack Simpson',
#   'País': 'ENG',
#   'Posc': 'Defensa',
#   'Equipo': 'Bournemouth',
#   'Edad': 22,
#   'Nacimiento': 1996.0,
#   'PJ': 4.0,
#   'Titular': 1.0,
#   'Mín': 241.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.1,
#   'Valor de mercado': 600000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271d8'),
#   'Jugador': 'Jack Stacey',
#   'País': 'ENG',
#   'Posc': 'Defensa',
#   'Equipo': 'Bournemouth',
#   'Edad': 26,
#   'Nacimiento': 1996.0,
#   'PJ': 14.5,
#   'Titular': 10.0,
#   'Mín': 924.0,
#   'Gls.': 0.0,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 2.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.3,
#   'Asistencias Esperadas': 1.1,
#   'Valor de mercado': 2200000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271d9'),
#   'Jugador': 'Jack Stephens',
#   'País': 'ENG',
#   'Posc': 'Defensa',
#   'Equipo': 'Southampton',
#   'Edad': 28,
#   'Nacimiento': 1994.0,
#   'PJ': 14.8,
#   'Titular': 13.2,
#   'Mín': 1203.6,
#   'Gls.': 0.2,
#   'Asistencias': 0.6,
#   'Goles+Asistencias': 0.8,
#   'Tarjetas Amarillas': 2.4,
#   'Tarjetas Rojas': 0.2,
#   'Goles Esperados': 0.44,
#   'Asistencias Esperadas': 0.44,
#   'Valor de mercado': 3000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271da'),
#   'Jugador': 'Jackson Tchatchoua',
#   'País': 'BEL',
#   'Posc': 'Defensa',
#   'Equipo': 'Hellas Verona',
#   'Edad': 22,
#   'Nacimiento': 2001.0,
#   'PJ': 5.0,
#   'Titular': 1.0,
#   'Mín': 161.0,
#   'Gls.': 0.0,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.7,
#   'Valor de mercado': 2000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271db'),
#   'Jugador': 'Jacob Brown',
#   'País': 'SCO',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Luton Town',
#   'Edad': 25,
#   'Nacimiento': 1998.0,
#   'PJ': 12.0,
#   'Titular': 7.0,
#   'Mín': 587.0,
#   'Gls.': 1.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 2.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 2.3,
#   'Asistencias Esperadas': 0.6,
#   'Valor de mercado': 4000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271dc'),
#   'Jugador': 'Jacob Bruun Larsen',
#   'País': 'DEN',
#   'Posc': 'Delantero',
#   'Equipo': 'Burnley',
#   'Edad': 25,
#   'Nacimiento': 1998.0,
#   'PJ': 11.0,
#   'Titular': 0.0,
#   'Mín': 191.0,
#   'Gls.': 1.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.5,
#   'Asistencias Esperadas': 0.1,
#   'Valor de mercado': 3000000.0},
#  {'_id': ObjectId('656dc7c4de86b9b4130271df'),
#   'Jugador': 'Jacopo Da Riva',
#   'País': 'ITA',
#   'Posc': 'Centrocampista',
#   'Equipo': 'Atalanta',
#   'Edad': 18,
#   'Nacimiento': 2000.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 1.0,
#   'Gls.': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Valor de mercado': 1200000.0},
#  ...]
