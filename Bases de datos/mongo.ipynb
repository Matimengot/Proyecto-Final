# %%
from pymongo import MongoClient

import pandas as pd

# %%
cursor = MongoClient()   # no esta escrita la string de conexion

cursor
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
str_conn = 'mongodb://localhost:27017'   # str_con por defecto

cursor = MongoClient(str_conn)

cursor
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
futbol = cursor['Futbol']

# %%
db = cursor.futbol

# %%
cursor.list_database_names()
# Out:
# ['admin', 'companies', 'config', 'local']

# %%
collection = db['Jugadores']

# %%
# Importo mi csv
jugadores = pd.read_csv('../csv/csv_limpios/tabla_completa_lp.csv')

# %% [markdown]
# #### Preparo los datos

# %%
# Convierto mi dataframe en un diccionario
jugadores_dict = jugadores.to_dict('records')

# %%
# Inserto mi diccionario en la coleccion
collection.insert_many(jugadores_dict)

# %%
# Verifico que se haya insertado correctamente
collection.find_one()
# Out:
# {'_id': ObjectId('656eec6d5cc59deefd7edbd8'),
#  'Jugador': 'Aaron Connolly',
#  'Pais': 'IRL',
#  'Posicion': 'Delantero',
#  'Equipo': 'Brighton',
#  'Edad': 21,
#  'Nacimiento': 2000.0,
#  'PJ': 15.0,
#  'Titular': 8.0,
#  'Mín': 735.0,
#  'Goles': 1.6666666666666667,
#  'Asistencias': 0.6666666666666666,
#  'Goles+Asistencias': 2.333333333333333,
#  'Tarjetas Amarillas': 0.0,
#  'Tarjetas Rojas': 0.0,
#  'Goles Esperados': 2.8000000000000003,
#  'Asistencias Esperadas': 0.2666666666666666,
#  'Temporada': '2019-2020',
#  'Valor de mercado': 3500000.0}

# %% [markdown]
# ### Pruebo querys

# %%
#intento usar querys
query = {'$and': [{'Edad': {'$lt': 26}},
                  {'Edad': {'$gt': 24}}
                 ]}

len(list(collection.find(query)))
# Out:
# 279

# %%
# ahora una query para valor de mercado menos a 10 millones
query = {'Valor de mercado': {'$lt': 10000000}}

list(collection.find(query))
# Out:
# [{'_id': ObjectId('656eec6d5cc59deefd7edbd8'),
#   'Jugador': 'Aaron Connolly',
#   'Pais': 'IRL',
#   'Posicion': 'Delantero',
#   'Equipo': 'Brighton',
#   'Edad': 21,
#   'Nacimiento': 2000.0,
#   'PJ': 15.0,
#   'Titular': 8.0,
#   'Mín': 735.0,
#   'Goles': 1.6666666666666667,
#   'Asistencias': 0.6666666666666666,
#   'Goles+Asistencias': 2.333333333333333,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 2.8000000000000003,
#   'Asistencias Esperadas': 0.2666666666666666,
#   'Temporada': '2019-2020',
#   'Valor de mercado': 3500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbd9'),
#   'Jugador': 'Aaron Cresswell',
#   'Pais': 'ENG',
#   'Posicion': 'Defensa',
#   'Equipo': 'West Ham',
#   'Edad': 32,
#   'Nacimiento': 1989.0,
#   'PJ': 30.33333333333333,
#   'Titular': 29.166666666666668,
#   'Mín': 2586.0,
#   'Goles': 1.0,
#   'Asistencias': 2.6666666666666665,
#   'Goles+Asistencias': 3.6666666666666665,
#   'Tarjetas Amarillas': 4.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.8500000000000001,
#   'Asistencias Esperadas': 3.483333333333333,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 1200000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbdc'),
#   'Jugador': 'Aaron Ramsey',
#   'Pais': 'WAL',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Arsenal',
#   'Edad': 30,
#   'Nacimiento': 1990.0,
#   'PJ': 20.2,
#   'Titular': 12.0,
#   'Mín': 1083.2,
#   'Goles': 3.2,
#   'Asistencias': 3.8,
#   'Goles+Asistencias': 7.0,
#   'Tarjetas Amarillas': 0.8,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 3.24,
#   'Asistencias Esperadas': 2.38,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 2500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbdd'),
#   'Jugador': 'Aaron Rowe',
#   'Pais': 'ENG',
#   'Posicion': 'Delantero',
#   'Equipo': 'Huddersfield',
#   'Edad': 17,
#   'Nacimiento': 2000.0,
#   'PJ': 2.0,
#   'Titular': 1.0,
#   'Mín': 69.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2018-2019',
#   'Valor de mercado': 150000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbdf'),
#   'Jugador': 'Aarón Escandell',
#   'Pais': 'ESP',
#   'Posicion': 'PO',
#   'Equipo': 'Granada',
#   'Edad': 25,
#   'Nacimiento': 1995.0,
#   'PJ': 4.0,
#   'Titular': 3.6666666666666665,
#   'Mín': 334.6666666666667,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.6666666666666666,
#   'Tarjetas Rojas': 0.3333333333333333,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2019-2020',
#   'Valor de mercado': 1000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbe0'),
#   'Jugador': 'Aarón Martín',
#   'Pais': 'ESP',
#   'Posicion': 'Defensa',
#   'Equipo': 'Espanyol',
#   'Edad': 23,
#   'Nacimiento': 1997.0,
#   'PJ': 25.5,
#   'Titular': 24.0,
#   'Mín': 2177.5,
#   'Goles': 0.0,
#   'Asistencias': 1.5,
#   'Goles+Asistencias': 1.5,
#   'Tarjetas Amarillas': 3.5,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.15,
#   'Asistencias Esperadas': 1.7999999999999998,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 7000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbe1'),
#   'Jugador': 'Abdallahi Mahmoud',
#   'Pais': 'MTN',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Alavés',
#   'Edad': 20,
#   'Nacimiento': 2000.0,
#   'PJ': 2.5,
#   'Titular': 1.0,
#   'Mín': 109.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.5,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2019-2020',
#   'Valor de mercado': 500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbe2'),
#   'Jugador': 'Abdelhamid Sabiri',
#   'Pais': 'MAR',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Huddersfield',
#   'Edad': 25,
#   'Nacimiento': 1996.0,
#   'PJ': 9.75,
#   'Titular': 6.0,
#   'Mín': 557.5,
#   'Goles': 1.25,
#   'Asistencias': 0.75,
#   'Goles+Asistencias': 2.0,
#   'Tarjetas Amarillas': 2.25,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 1.175,
#   'Asistencias Esperadas': 0.775,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 2500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbe4'),
#   'Jugador': 'Abdou Harroui',
#   'Pais': 'NED',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Sassuolo',
#   'Edad': 24,
#   'Nacimiento': 1998.0,
#   'PJ': 22.5,
#   'Titular': 4.0,
#   'Mín': 549.5,
#   'Goles': 1.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 2.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 1.0,
#   'Asistencias Esperadas': 0.25,
#   'Temporada': '2021-2022',
#   'Valor de mercado': 2700000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbe5'),
#   'Jugador': 'Abdou Lahat Diakhate',
#   'Pais': 'SEN',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Parma',
#   'Edad': 19,
#   'Nacimiento': 1998.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 1.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2018-2019',
#   'Valor de mercado': 10000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbe6'),
#   'Jugador': 'Abdoulay Diaby',
#   'Pais': 'MLI',
#   'Posicion': 'Defensa',
#   'Equipo': 'Getafe',
#   'Edad': 29,
#   'Nacimiento': 1991.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 18.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.3,
#   'Asistencias Esperadas': 0.1,
#   'Temporada': '2020-2021',
#   'Valor de mercado': 1200000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbe7'),
#   'Jugador': 'Abdoulaye Ba',
#   'Pais': 'SEN',
#   'Posicion': 'Defensa',
#   'Equipo': 'Rayo Vallecano',
#   'Edad': 27,
#   'Nacimiento': 1991.0,
#   'PJ': 26.0,
#   'Titular': 25.0,
#   'Mín': 2110.0,
#   'Goles': 1.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 4.0,
#   'Tarjetas Rojas': 2.0,
#   'Goles Esperados': 1.3,
#   'Asistencias Esperadas': 0.1,
#   'Temporada': '2018-2019',
#   'Valor de mercado': 300000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbe9'),
#   'Jugador': 'Abdoulaye Touré',
#   'Pais': 'GUI',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Genoa',
#   'Edad': 27,
#   'Nacimiento': 1994.0,
#   'PJ': 8.0,
#   'Titular': 6.0,
#   'Mín': 430.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.1,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2021-2022',
#   'Valor de mercado': 1200000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbea'),
#   'Jugador': 'Abdul Mumin',
#   'Pais': 'GHA',
#   'Posicion': 'Defensa',
#   'Equipo': 'Rayo Vallecano',
#   'Edad': 24,
#   'Nacimiento': 1998.0,
#   'PJ': 16.0,
#   'Titular': 9.0,
#   'Mín': 922.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 2.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.4,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2022-2023',
#   'Valor de mercado': 1500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbeb'),
#   'Jugador': 'Abdón Prats',
#   'Pais': 'ESP',
#   'Posicion': 'Delantero',
#   'Equipo': 'Mallorca',
#   'Edad': 29,
#   'Nacimiento': 1992.0,
#   'PJ': 23.0,
#   'Titular': 2.6666666666666665,
#   'Mín': 445.3333333333333,
#   'Goles': 1.3333333333333333,
#   'Asistencias': 0.3333333333333333,
#   'Goles+Asistencias': 1.6666666666666667,
#   'Tarjetas Amarillas': 1.6666666666666667,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 1.2333333333333334,
#   'Asistencias Esperadas': 0.6999999999999998,
#   'Temporada': '2019-2020',
#   'Valor de mercado': 2000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbed'),
#   'Jugador': 'Abner',
#   'Pais': 'BRA',
#   'Posicion': 'Defensa',
#   'Equipo': 'Betis',
#   'Edad': 22,
#   'Nacimiento': 2000.0,
#   'PJ': 13.0,
#   'Titular': 7.0,
#   'Mín': 607.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 2.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 1.7,
#   'Asistencias Esperadas': 0.1,
#   'Temporada': '2022-2023',
#   'Valor de mercado': 7000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbee'),
#   'Jugador': 'Aboubakar Kamara',
#   'Pais': 'MTN',
#   'Posicion': 'Delantero',
#   'Equipo': 'Fulham',
#   'Edad': 25,
#   'Nacimiento': 1995.0,
#   'PJ': 12.0,
#   'Titular': 3.5,
#   'Mín': 504.0,
#   'Goles': 1.5,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 1.5,
#   'Tarjetas Amarillas': 1.5,
#   'Tarjetas Rojas': 0.5,
#   'Goles Esperados': 2.1,
#   'Asistencias Esperadas': 0.5,
#   'Temporada': '2018-2019',
#   'Valor de mercado': 2500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbf0'),
#   'Jugador': 'Achraf Lazaar',
#   'Pais': 'MAR',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Benevento',
#   'Edad': 25,
#   'Nacimiento': 1992.0,
#   'PJ': 9.0,
#   'Titular': 6.0,
#   'Mín': 478.0,
#   'Goles': 1.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.3,
#   'Asistencias Esperadas': 0.2,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 200000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbf1'),
#   'Jugador': 'Adalberto Peñaranda',
#   'Pais': 'VEN',
#   'Posicion': 'Delantero',
#   'Equipo': 'Málaga',
#   'Edad': 20,
#   'Nacimiento': 1997.0,
#   'PJ': 13.0,
#   'Titular': 11.0,
#   'Mín': 802.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 3.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.7,
#   'Asistencias Esperadas': 0.4,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 400000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbf3'),
#   'Jugador': 'Adam Forshaw',
#   'Pais': 'ENG',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Leeds United',
#   'Edad': 30,
#   'Nacimiento': 1991.0,
#   'PJ': 17.0,
#   'Titular': 11.0,
#   'Mín': 1004.5,
#   'Goles': 0.0,
#   'Asistencias': 0.5,
#   'Goles+Asistencias': 0.5,
#   'Tarjetas Amarillas': 2.5,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.25,
#   'Asistencias Esperadas': 0.95,
#   'Temporada': '2021-2022',
#   'Valor de mercado': 1200000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbf4'),
#   'Jugador': 'Adam Idah',
#   'Pais': 'IRL',
#   'Posicion': 'Delantero',
#   'Equipo': 'Norwich City',
#   'Edad': 20,
#   'Nacimiento': 2001.0,
#   'PJ': 14.5,
#   'Titular': 3.5,
#   'Mín': 426.5,
#   'Goles': 0.5,
#   'Asistencias': 0.5,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 1.65,
#   'Asistencias Esperadas': 0.3,
#   'Temporada': '2019-2020',
#   'Valor de mercado': 2000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbf5'),
#   'Jugador': 'Adam Lallana',
#   'Pais': 'ENG',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Liverpool',
#   'Edad': 34,
#   'Nacimiento': 1988.0,
#   'PJ': 18.33333333333333,
#   'Titular': 9.166666666666666,
#   'Mín': 839.5,
#   'Goles': 0.6666666666666666,
#   'Asistencias': 0.6666666666666666,
#   'Goles+Asistencias': 1.3333333333333333,
#   'Tarjetas Amarillas': 1.1666666666666667,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 1.0333333333333334,
#   'Asistencias Esperadas': 1.0,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 1200000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbf6'),
#   'Jugador': 'Adam Marušić',
#   'Pais': 'MNE',
#   'Posicion': 'Defensa',
#   'Equipo': 'Lazio',
#   'Edad': 29,
#   'Nacimiento': 1992.0,
#   'PJ': 29.166666666666668,
#   'Titular': 26.0,
#   'Mín': 2337.1666666666665,
#   'Goles': 1.5,
#   'Asistencias': 1.8333333333333333,
#   'Goles+Asistencias': 3.333333333333333,
#   'Tarjetas Amarillas': 4.166666666666667,
#   'Tarjetas Rojas': 0.6666666666666666,
#   'Goles Esperados': 1.5166666666666664,
#   'Asistencias Esperadas': 1.5,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 8000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbf7'),
#   'Jugador': 'Adam Masina',
#   'Pais': 'MAR',
#   'Posicion': 'Defensa',
#   'Equipo': 'Watford',
#   'Edad': 28,
#   'Nacimiento': 1994.0,
#   'PJ': 20.6,
#   'Titular': 17.0,
#   'Mín': 1504.2,
#   'Goles': 0.6,
#   'Asistencias': 0.6,
#   'Goles+Asistencias': 1.2,
#   'Tarjetas Amarillas': 3.6,
#   'Tarjetas Rojas': 0.2,
#   'Goles Esperados': 0.66,
#   'Asistencias Esperadas': 0.82,
#   'Temporada': '2018-2019',
#   'Valor de mercado': 2500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbf8'),
#   'Jugador': 'Adam Obert',
#   'Pais': 'SVK',
#   'Posicion': 'Defensa',
#   'Equipo': 'Cagliari',
#   'Edad': 18,
#   'Nacimiento': 2002.0,
#   'PJ': 6.0,
#   'Titular': 3.0,
#   'Mín': 274.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2021-2022',
#   'Valor de mercado': 1800000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbf9'),
#   'Jugador': 'Adam Ounas',
#   'Pais': 'ALG',
#   'Posicion': 'Delantero',
#   'Equipo': 'Napoli',
#   'Edad': 25,
#   'Nacimiento': 1996.0,
#   'PJ': 10.666666666666666,
#   'Titular': 4.166666666666667,
#   'Mín': 413.6666666666667,
#   'Goles': 1.1666666666666667,
#   'Asistencias': 0.6666666666666666,
#   'Goles+Asistencias': 1.8333333333333333,
#   'Tarjetas Amarillas': 0.3333333333333333,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.9166666666666666,
#   'Asistencias Esperadas': 1.1333333333333333,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 7000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbfa'),
#   'Jugador': 'Adam Smith',
#   'Pais': 'ENG',
#   'Posicion': 'Defensa',
#   'Equipo': 'Bournemouth',
#   'Edad': 31,
#   'Nacimiento': 1991.0,
#   'PJ': 28.25,
#   'Titular': 26.25,
#   'Mín': 2283.75,
#   'Goles': 0.5,
#   'Asistencias': 1.5,
#   'Goles+Asistencias': 2.0,
#   'Tarjetas Amarillas': 7.25,
#   'Tarjetas Rojas': 0.25,
#   'Goles Esperados': 0.575,
#   'Asistencias Esperadas': 1.15,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 1200000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbfc'),
#   'Jugador': 'Adama Diakhaby',
#   'Pais': 'FRA',
#   'Posicion': 'Delantero',
#   'Equipo': 'Huddersfield',
#   'Edad': 22,
#   'Nacimiento': 1996.0,
#   'PJ': 12.0,
#   'Titular': 6.0,
#   'Mín': 552.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.6,
#   'Asistencias Esperadas': 0.5,
#   'Temporada': '2018-2019',
#   'Valor de mercado': 600000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbfd'),
#   'Jugador': 'Adama Soumaoro',
#   'Pais': 'FRA',
#   'Posicion': 'Defensa',
#   'Equipo': 'Genoa',
#   'Edad': 30,
#   'Nacimiento': 1992.0,
#   'PJ': 19.75,
#   'Titular': 18.5,
#   'Mín': 1631.25,
#   'Goles': 0.5,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.5,
#   'Tarjetas Amarillas': 4.25,
#   'Tarjetas Rojas': 0.75,
#   'Goles Esperados': 0.7499999999999999,
#   'Asistencias Esperadas': 0.05,
#   'Temporada': '2019-2020',
#   'Valor de mercado': 3000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edbff'),
#   'Jugador': 'Adel Taarabt',
#   'Pais': 'MAR',
#   'Posicion': 'Delantero',
#   'Equipo': 'Genoa',
#   'Edad': 28,
#   'Nacimiento': 1989.0,
#   'PJ': 22.0,
#   'Titular': 18.0,
#   'Mín': 1615.0,
#   'Goles': 2.0,
#   'Asistencias': 2.0,
#   'Goles+Asistencias': 4.0,
#   'Tarjetas Amarillas': 4.0,
#   'Tarjetas Rojas': 1.0,
#   'Goles Esperados': 1.5,
#   'Asistencias Esperadas': 2.7,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 1000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc00'),
#   'Jugador': 'Adem Ljajić',
#   'Pais': 'SRB',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Torino',
#   'Edad': 26,
#   'Nacimiento': 1991.0,
#   'PJ': 14.0,
#   'Titular': 11.5,
#   'Mín': 1098.0,
#   'Goles': 3.0,
#   'Asistencias': 5.0,
#   'Goles+Asistencias': 8.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 2.2,
#   'Asistencias Esperadas': 4.2,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc02'),
#   'Jugador': 'Adnan Januzaj',
#   'Pais': 'BEL',
#   'Posicion': 'Delantero',
#   'Equipo': 'Real Sociedad',
#   'Edad': 27,
#   'Nacimiento': 1995.0,
#   'PJ': 22.33333333333333,
#   'Titular': 12.333333333333334,
#   'Mín': 1113.3333333333333,
#   'Goles': 2.333333333333333,
#   'Asistencias': 2.6666666666666665,
#   'Goles+Asistencias': 5.0,
#   'Tarjetas Amarillas': 2.5,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 3.283333333333333,
#   'Asistencias Esperadas': 3.0666666666666664,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 4000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc03'),
#   'Jugador': 'Adolfo Gaich',
#   'Pais': 'ARG',
#   'Posicion': 'Delantero',
#   'Equipo': 'Benevento',
#   'Edad': 23,
#   'Nacimiento': 1999.0,
#   'PJ': 15.5,
#   'Titular': 8.5,
#   'Mín': 747.0,
#   'Goles': 2.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 2.0,
#   'Tarjetas Amarillas': 1.5,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 2.65,
#   'Asistencias Esperadas': 0.4,
#   'Temporada': '2020-2021',
#   'Valor de mercado': 1800000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc04'),
#   'Jugador': 'Adrian Mariappa',
#   'Pais': 'JAM',
#   'Posicion': 'Defensa',
#   'Equipo': 'Watford',
#   'Edad': 32,
#   'Nacimiento': 1986.0,
#   'PJ': 24.666666666666668,
#   'Titular': 19.666666666666668,
#   'Mín': 1883.3333333333333,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 4.333333333333333,
#   'Tarjetas Rojas': 0.3333333333333333,
#   'Goles Esperados': 0.5333333333333333,
#   'Asistencias Esperadas': 0.3333333333333333,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 100000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc05'),
#   'Jugador': 'Adrian Stoian',
#   'Pais': 'ROU',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Crotone',
#   'Edad': 26,
#   'Nacimiento': 1991.0,
#   'PJ': 32.0,
#   'Titular': 26.0,
#   'Mín': 2133.0,
#   'Goles': 2.0,
#   'Asistencias': 4.0,
#   'Goles+Asistencias': 6.0,
#   'Tarjetas Amarillas': 5.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 1.6,
#   'Asistencias Esperadas': 2.4,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 75000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc06'),
#   'Jugador': 'Adrian Šemper',
#   'Pais': 'CRO',
#   'Posicion': 'PO',
#   'Equipo': 'Chievo',
#   'Edad': 23,
#   'Nacimiento': 1998.0,
#   'PJ': 3.5,
#   'Titular': 3.5,
#   'Mín': 315.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2018-2019',
#   'Valor de mercado': 1200000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc08'),
#   'Jugador': 'Adrien Silva',
#   'Pais': 'POR',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Leicester City',
#   'Edad': 32,
#   'Nacimiento': 1989.0,
#   'PJ': 13.75,
#   'Titular': 10.0,
#   'Mín': 882.75,
#   'Goles': 0.25,
#   'Asistencias': 0.75,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 3.5,
#   'Tarjetas Rojas': 0.5,
#   'Goles Esperados': 0.275,
#   'Asistencias Esperadas': 0.5,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 1000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc09'),
#   'Jugador': 'Adrien Tameze',
#   'Pais': 'CMR',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Atalanta',
#   'Edad': 28,
#   'Nacimiento': 1994.0,
#   'PJ': 28.75,
#   'Titular': 22.75,
#   'Mín': 2030.0,
#   'Goles': 1.25,
#   'Asistencias': 0.5,
#   'Goles+Asistencias': 1.75,
#   'Tarjetas Amarillas': 3.25,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.825,
#   'Asistencias Esperadas': 0.8749999999999999,
#   'Temporada': '2019-2020',
#   'Valor de mercado': 6000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc0a'),
#   'Jugador': 'Adrià Pedrosa',
#   'Pais': 'ESP',
#   'Posicion': 'Defensa',
#   'Equipo': 'Espanyol',
#   'Edad': 24,
#   'Nacimiento': 1998.0,
#   'PJ': 17.5,
#   'Titular': 13.0,
#   'Mín': 1199.75,
#   'Goles': 0.75,
#   'Asistencias': 0.25,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 3.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.7000000000000001,
#   'Asistencias Esperadas': 0.7749999999999999,
#   'Temporada': '2018-2019',
#   'Valor de mercado': 5000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc0b'),
#   'Jugador': 'Adrián Butzke',
#   'Pais': 'ESP',
#   'Posicion': 'Delantero',
#   'Equipo': 'Granada',
#   'Edad': 22,
#   'Nacimiento': 1999.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 1.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2021-2022',
#   'Valor de mercado': 400000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc0c'),
#   'Jugador': 'Adrián Diéguez',
#   'Pais': 'ESP',
#   'Posicion': 'Defensa',
#   'Equipo': 'Alavés',
#   'Edad': 22,
#   'Nacimiento': 1996.0,
#   'PJ': 7.5,
#   'Titular': 7.0,
#   'Mín': 592.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 4.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.1,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 600000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc0d'),
#   'Jugador': 'Adrián Guerrero',
#   'Pais': 'ESP',
#   'Posicion': 'Defensa',
#   'Equipo': 'Valencia',
#   'Edad': 21,
#   'Nacimiento': 1998.0,
#   'PJ': 2.0,
#   'Titular': 1.0,
#   'Mín': 126.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2019-2020',
#   'Valor de mercado': 2000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc0e'),
#   'Jugador': 'Adrián Marín',
#   'Pais': 'ESP',
#   'Posicion': 'Defensa',
#   'Equipo': 'Villarreal',
#   'Edad': 23,
#   'Nacimiento': 1997.0,
#   'PJ': 7.0,
#   'Titular': 3.4,
#   'Mín': 347.4,
#   'Goles': 0.0,
#   'Asistencias': 0.2,
#   'Goles+Asistencias': 0.2,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.24,
#   'Asistencias Esperadas': 0.1,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 1500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc0f'),
#   'Jugador': 'Adrián Ramos',
#   'Pais': 'COL',
#   'Posicion': 'Delantero',
#   'Equipo': 'Granada',
#   'Edad': 33,
#   'Nacimiento': 1986.0,
#   'PJ': 7.0,
#   'Titular': 2.0,
#   'Mín': 226.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.4,
#   'Asistencias Esperadas': 0.7,
#   'Temporada': '2019-2020',
#   'Valor de mercado': 300000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc10'),
#   'Jugador': 'Adu Ares',
#   'Pais': 'ESP',
#   'Posicion': 'Delantero',
#   'Equipo': 'Athletic Club',
#   'Edad': 20,
#   'Nacimiento': 2001.0,
#   'PJ': 8.0,
#   'Titular': 0.0,
#   'Mín': 84.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.1,
#   'Asistencias Esperadas': 0.2,
#   'Temporada': '2022-2023',
#   'Valor de mercado': 500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc11'),
#   'Jugador': 'Afriyie Acquah',
#   'Pais': 'GHA',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Torino',
#   'Edad': 26,
#   'Nacimiento': 1992.0,
#   'PJ': 25.0,
#   'Titular': 14.0,
#   'Mín': 1230.5,
#   'Goles': 1.5,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 1.5,
#   'Tarjetas Amarillas': 4.0,
#   'Tarjetas Rojas': 1.0,
#   'Goles Esperados': 0.8999999999999999,
#   'Asistencias Esperadas': 0.7,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 300000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc12'),
#   'Jugador': 'Ager Aketxe',
#   'Pais': 'ESP',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Athletic Club',
#   'Edad': 23,
#   'Nacimiento': 1993.0,
#   'PJ': 3.0,
#   'Titular': 0.0,
#   'Mín': 37.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.1,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 1000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc13'),
#   'Jugador': 'Agustín Marchesín',
#   'Pais': 'ARG',
#   'Posicion': 'PO',
#   'Equipo': 'Celta Vigo',
#   'Edad': 34,
#   'Nacimiento': 1988.0,
#   'PJ': 19.0,
#   'Titular': 19.0,
#   'Mín': 1710.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 2.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2022-2023',
#   'Valor de mercado': 1500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc14'),
#   'Jugador': 'Agustín Álvarez Martínez',
#   'Pais': 'URU',
#   'Posicion': 'Delantero',
#   'Equipo': 'Sassuolo',
#   'Edad': 21,
#   'Nacimiento': 2001.0,
#   'PJ': 22.0,
#   'Titular': 1.0,
#   'Mín': 368.0,
#   'Goles': 1.0,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 2.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 1.5,
#   'Asistencias Esperadas': 0.4,
#   'Temporada': '2022-2023',
#   'Valor de mercado': 8000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc15'),
#   'Jugador': 'Ahmad Benali',
#   'Pais': 'LBY',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Crotone',
#   'Edad': 28,
#   'Nacimiento': 1992.0,
#   'PJ': 14.0,
#   'Titular': 12.5,
#   'Mín': 1012.5,
#   'Goles': 0.5,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 1.5,
#   'Tarjetas Amarillas': 2.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.75,
#   'Asistencias Esperadas': 0.75,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 900000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc16'),
#   'Jugador': 'Ahmed Hegazi',
#   'Pais': 'EGY',
#   'Posicion': 'Defensa',
#   'Equipo': 'West Brom',
#   'Edad': 29,
#   'Nacimiento': 1991.0,
#   'PJ': 19.5,
#   'Titular': 19.5,
#   'Mín': 1738.0,
#   'Goles': 1.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 2.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.85,
#   'Asistencias Esperadas': 0.3,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 2500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc17'),
#   'Jugador': 'Aihen Muñoz',
#   'Pais': 'ESP',
#   'Posicion': 'Defensa',
#   'Equipo': 'Real Sociedad',
#   'Edad': 24,
#   'Nacimiento': 1997.0,
#   'PJ': 17.0,
#   'Titular': 14.2,
#   'Mín': 1248.0,
#   'Goles': 0.0,
#   'Asistencias': 0.4,
#   'Goles+Asistencias': 0.4,
#   'Tarjetas Amarillas': 2.6,
#   'Tarjetas Rojas': 0.2,
#   'Goles Esperados': 0.1399999999999999,
#   'Asistencias Esperadas': 0.44,
#   'Temporada': '2018-2019',
#   'Valor de mercado': 6000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc19'),
#   'Jugador': 'Aimar Sher',
#   'Pais': 'SWE',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Spezia',
#   'Edad': 18,
#   'Nacimiento': 2002.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 45.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2021-2022',
#   'Valor de mercado': 750000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc1a'),
#   'Jugador': 'Ainsley Maitland-Niles',
#   'Pais': 'ENG',
#   'Posicion': 'Defensa',
#   'Equipo': 'Arsenal',
#   'Edad': 24,
#   'Nacimiento': 1997.0,
#   'PJ': 14.375,
#   'Titular': 9.375,
#   'Mín': 896.125,
#   'Goles': 0.125,
#   'Asistencias': 0.375,
#   'Goles+Asistencias': 0.5,
#   'Tarjetas Amarillas': 1.75,
#   'Tarjetas Rojas': 0.25,
#   'Goles Esperados': 0.325,
#   'Asistencias Esperadas': 0.7125,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 6000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc1b'),
#   'Jugador': 'Aitor Fernández',
#   'Pais': 'ESP',
#   'Posicion': 'PO',
#   'Equipo': 'Levante',
#   'Edad': 31,
#   'Nacimiento': 1991.0,
#   'PJ': 23.0,
#   'Titular': 23.0,
#   'Mín': 2069.2,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.8,
#   'Tarjetas Rojas': 0.2,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.08,
#   'Temporada': '2018-2019',
#   'Valor de mercado': 3000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc1c'),
#   'Jugador': 'Aitor Paredes',
#   'Pais': 'ESP',
#   'Posicion': 'Defensa',
#   'Equipo': 'Athletic Club',
#   'Edad': 22,
#   'Nacimiento': 2000.0,
#   'PJ': 16.0,
#   'Titular': 9.0,
#   'Mín': 859.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 3.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.5,
#   'Asistencias Esperadas': 0.4,
#   'Temporada': '2022-2023',
#   'Valor de mercado': 8000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc1d'),
#   'Jugador': 'Aitor Ruibal',
#   'Pais': 'ESP',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Betis',
#   'Edad': 26,
#   'Nacimiento': 1996.0,
#   'PJ': 20.0,
#   'Titular': 11.6,
#   'Mín': 1026.4,
#   'Goles': 0.4,
#   'Asistencias': 0.4,
#   'Goles+Asistencias': 0.8,
#   'Tarjetas Amarillas': 3.2,
#   'Tarjetas Rojas': 0.2,
#   'Goles Esperados': 1.0799999999999998,
#   'Asistencias Esperadas': 1.4,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 5000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc1e'),
#   'Jugador': 'Ajdin Hrustic',
#   'Pais': 'AUS',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Hellas Verona',
#   'Edad': 26,
#   'Nacimiento': 1996.0,
#   'PJ': 6.0,
#   'Titular': 3.0,
#   'Mín': 226.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.3,
#   'Asistencias Esperadas': 0.6,
#   'Temporada': '2022-2023',
#   'Valor de mercado': 900000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc1f'),
#   'Jugador': 'Akin Famewo',
#   'Pais': 'ENG',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Norwich City',
#   'Edad': 20,
#   'Nacimiento': 1998.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 1.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2019-2020',
#   'Valor de mercado': 300000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc20'),
#   'Jugador': 'Alan Empereur',
#   'Pais': 'BRA',
#   'Posicion': 'Defensa',
#   'Equipo': 'Hellas Verona',
#   'Edad': 26,
#   'Nacimiento': 1994.0,
#   'PJ': 8.5,
#   'Titular': 6.0,
#   'Mín': 537.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 2.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.1,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2019-2020',
#   'Valor de mercado': 750000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc21'),
#   'Jugador': 'Alassane Sidibe',
#   'Pais': 'CIV',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Atalanta',
#   'Edad': 19,
#   'Nacimiento': 2002.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 6.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2021-2022',
#   'Valor de mercado': 750000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc25'),
#   'Jugador': 'Alberto Basso',
#   'Pais': 'ITA',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Cremonese',
#   'Edad': 18,
#   'Nacimiento': 2004.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 16.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2022-2023',
#   'Valor de mercado': 100000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc26'),
#   'Jugador': 'Alberto Brignoli',
#   'Pais': 'ITA',
#   'Posicion': 'PO',
#   'Equipo': 'Benevento',
#   'Edad': 25,
#   'Nacimiento': 1991.0,
#   'PJ': 13.0,
#   'Titular': 11.0,
#   'Mín': 1126.0,
#   'Goles': 1.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 2.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.1,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 1800000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc27'),
#   'Jugador': 'Alberto Cerri',
#   'Pais': 'ITA',
#   'Posicion': 'Delantero',
#   'Equipo': 'Cagliari',
#   'Edad': 24,
#   'Nacimiento': 1996.0,
#   'PJ': 14.25,
#   'Titular': 4.0,
#   'Mín': 425.75,
#   'Goles': 0.75,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.75,
#   'Tarjetas Amarillas': 1.5,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 1.725,
#   'Asistencias Esperadas': 0.6,
#   'Temporada': '2018-2019',
#   'Valor de mercado': 2000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc28'),
#   'Jugador': 'Alberto Del Moral',
#   'Pais': 'ESP',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Villarreal',
#   'Edad': 22,
#   'Nacimiento': 2000.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 5.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2022-2023',
#   'Valor de mercado': 1000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc29'),
#   'Jugador': 'Alberto García',
#   'Pais': 'ESP',
#   'Posicion': 'PO',
#   'Equipo': 'Rayo Vallecano',
#   'Edad': 33,
#   'Nacimiento': 1985.0,
#   'PJ': 17.0,
#   'Titular': 17.0,
#   'Mín': 1530.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2018-2019',
#   'Valor de mercado': 3000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc2a'),
#   'Jugador': 'Alberto Grassi',
#   'Pais': 'ITA',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'SPAL',
#   'Edad': 27,
#   'Nacimiento': 1995.0,
#   'PJ': 21.5,
#   'Titular': 15.0,
#   'Mín': 1316.8333333333333,
#   'Goles': 0.6666666666666666,
#   'Asistencias': 0.3333333333333333,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 3.5,
#   'Tarjetas Rojas': 0.1666666666666666,
#   'Goles Esperados': 1.0499999999999998,
#   'Asistencias Esperadas': 0.6666666666666666,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 2000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc2b'),
#   'Jugador': 'Alberto López',
#   'Pais': 'ESP',
#   'Posicion': 'Defensa',
#   'Equipo': 'Málaga',
#   'Edad': 22,
#   'Nacimiento': 1995.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 45.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 7000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc2c'),
#   'Jugador': 'Alberto Moreno',
#   'Pais': 'ESP',
#   'Posicion': 'Defensa',
#   'Equipo': 'Liverpool',
#   'Edad': 30,
#   'Nacimiento': 1992.0,
#   'PJ': 14.833333333333334,
#   'Titular': 10.333333333333334,
#   'Mín': 933.8333333333334,
#   'Goles': 0.5,
#   'Asistencias': 0.5,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 2.833333333333333,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.9333333333333336,
#   'Asistencias Esperadas': 0.7666666666666666,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 2000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc2d'),
#   'Jugador': 'Alberto Paleari',
#   'Pais': 'ITA',
#   'Posicion': 'PO',
#   'Equipo': 'Genoa',
#   'Edad': 27,
#   'Nacimiento': 1992.0,
#   'PJ': 3.0,
#   'Titular': 2.0,
#   'Mín': 206.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2020-2021',
#   'Valor de mercado': 700000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc2e'),
#   'Jugador': 'Alberto Paloschi',
#   'Pais': 'ITA',
#   'Posicion': 'Delantero',
#   'Equipo': 'SPAL',
#   'Edad': 29,
#   'Nacimiento': 1990.0,
#   'PJ': 19.0,
#   'Titular': 9.75,
#   'Mín': 922.25,
#   'Goles': 2.25,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 2.25,
#   'Tarjetas Amarillas': 1.25,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 2.95,
#   'Asistencias Esperadas': 0.5,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc2f'),
#   'Jugador': 'Alberto Perea',
#   'Pais': 'ESP',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Cádiz',
#   'Edad': 31,
#   'Nacimiento': 1990.0,
#   'PJ': 15.333333333333334,
#   'Titular': 8.333333333333334,
#   'Mín': 790.3333333333334,
#   'Goles': 0.6666666666666666,
#   'Asistencias': 1.3333333333333333,
#   'Goles+Asistencias': 2.0,
#   'Tarjetas Amarillas': 0.6666666666666666,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.9,
#   'Asistencias Esperadas': 1.0333333333333334,
#   'Temporada': '2020-2021',
#   'Valor de mercado': 1000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc30'),
#   'Jugador': 'Alberto Soro',
#   'Pais': 'ESP',
#   'Posicion': 'Delantero',
#   'Equipo': 'Granada',
#   'Edad': 22,
#   'Nacimiento': 1999.0,
#   'PJ': 15.5,
#   'Titular': 5.0,
#   'Mín': 485.5,
#   'Goles': 0.5,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 1.5,
#   'Tarjetas Amarillas': 0.5,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.75,
#   'Asistencias Esperadas': 0.4,
#   'Temporada': '2020-2021',
#   'Valor de mercado': 1500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc31'),
#   'Jugador': 'Albian Ajeti',
#   'Pais': 'SUI',
#   'Posicion': 'Delantero',
#   'Equipo': 'West Ham',
#   'Edad': 22,
#   'Nacimiento': 1997.0,
#   'PJ': 9.0,
#   'Titular': 0.0,
#   'Mín': 139.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.2,
#   'Asistencias Esperadas': 0.1,
#   'Temporada': '2019-2020',
#   'Valor de mercado': 1500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc32'),
#   'Jugador': 'Albin Ekdal',
#   'Pais': 'SWE',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Sampdoria',
#   'Edad': 33,
#   'Nacimiento': 1989.0,
#   'PJ': 30.6,
#   'Titular': 24.0,
#   'Mín': 2140.2,
#   'Goles': 0.6,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 1.6,
#   'Tarjetas Amarillas': 8.0,
#   'Tarjetas Rojas': 0.4,
#   'Goles Esperados': 1.42,
#   'Asistencias Esperadas': 1.0,
#   'Temporada': '2018-2019',
#   'Valor de mercado': 800000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc33'),
#   'Jugador': 'Aleandro Rosi',
#   'Pais': 'ITA',
#   'Posicion': 'Defensa',
#   'Equipo': 'Genoa',
#   'Edad': 30,
#   'Nacimiento': 1987.0,
#   'PJ': 24.0,
#   'Titular': 22.0,
#   'Mín': 1700.0,
#   'Goles': 0.0,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 5.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 1.1,
#   'Asistencias Esperadas': 1.1,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 150000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc34'),
#   'Jugador': 'Aleix Febas',
#   'Pais': 'ESP',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Mallorca',
#   'Edad': 25,
#   'Nacimiento': 1996.0,
#   'PJ': 16.5,
#   'Titular': 11.5,
#   'Mín': 903.5,
#   'Goles': 0.0,
#   'Asistencias': 1.5,
#   'Goles+Asistencias': 1.5,
#   'Tarjetas Amarillas': 2.5,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.2,
#   'Asistencias Esperadas': 0.9,
#   'Temporada': '2019-2020',
#   'Valor de mercado': 1500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc36'),
#   'Jugador': 'Aleix Garrido',
#   'Pais': 'ESP',
#   'Posicion': 'Delantero',
#   'Equipo': 'Barcelona',
#   'Edad': 18,
#   'Nacimiento': 2004.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 7.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2022-2023',
#   'Valor de mercado': 300000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc37'),
#   'Jugador': 'Aleix Vidal',
#   'Pais': 'ESP',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Barcelona',
#   'Edad': 32,
#   'Nacimiento': 1989.0,
#   'PJ': 20.5,
#   'Titular': 11.833333333333334,
#   'Mín': 1112.3333333333333,
#   'Goles': 0.8333333333333334,
#   'Asistencias': 1.5,
#   'Goles+Asistencias': 2.333333333333333,
#   'Tarjetas Amarillas': 5.166666666666667,
#   'Tarjetas Rojas': 0.1666666666666666,
#   'Goles Esperados': 0.8833333333333333,
#   'Asistencias Esperadas': 2.016666666666667,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 1000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc38'),
#   'Jugador': 'Alejandro Arribas',
#   'Pais': 'ESP',
#   'Posicion': 'Defensa',
#   'Equipo': 'La Coruña',
#   'Edad': 28,
#   'Nacimiento': 1989.0,
#   'PJ': 3.0,
#   'Titular': 3.0,
#   'Mín': 270.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.2,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 350000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc39'),
#   'Jugador': 'Alejandro Asensio',
#   'Pais': 'ESP',
#   'Posicion': 'Delantero',
#   'Equipo': 'Rayo Vallecano',
#   'Edad': 20,
#   'Nacimiento': 2000.0,
#   'PJ': 2.0,
#   'Titular': 0.0,
#   'Mín': 12.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2021-2022',
#   'Valor de mercado': 25000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc3b'),
#   'Jugador': 'Alejandro Blanco',
#   'Pais': 'ESP',
#   'Posicion': 'Delantero',
#   'Equipo': 'Alavés',
#   'Edad': 21,
#   'Nacimiento': 1998.0,
#   'PJ': 7.5,
#   'Titular': 3.0,
#   'Mín': 298.0,
#   'Goles': 0.5,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.5,
#   'Tarjetas Amarillas': 0.5,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.25,
#   'Asistencias Esperadas': 0.25,
#   'Temporada': '2018-2019',
#   'Valor de mercado': 600000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc3c'),
#   'Jugador': 'Alejandro Blesa',
#   'Pais': 'ESP',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Levante',
#   'Edad': 18,
#   'Nacimiento': 2002.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 6.5,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2019-2020',
#   'Valor de mercado': 300000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc3e'),
#   'Jugador': 'Alejandro Pozo Pozo',
#   'Pais': 'ESP',
#   'Posicion': 'Defensa',
#   'Equipo': 'Mallorca',
#   'Edad': 23,
#   'Nacimiento': 1999.0,
#   'PJ': 20.5,
#   'Titular': 15.0,
#   'Mín': 1401.25,
#   'Goles': 0.25,
#   'Asistencias': 1.25,
#   'Goles+Asistencias': 1.5,
#   'Tarjetas Amarillas': 1.5,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.3,
#   'Asistencias Esperadas': 1.55,
#   'Temporada': '2019-2020',
#   'Valor de mercado': 3000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc3f'),
#   'Jugador': 'Alejandro Primo',
#   'Pais': 'ESP',
#   'Posicion': 'PO',
#   'Equipo': 'Levante',
#   'Edad': 17,
#   'Nacimiento': 2004.0,
#   'PJ': 1.0,
#   'Titular': 1.0,
#   'Mín': 90.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2021-2022',
#   'Valor de mercado': 100000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc40'),
#   'Jugador': 'Alejandro Revuelta Montero',
#   'Pais': 'ESP',
#   'Posicion': 'Defensa',
#   'Equipo': 'Getafe',
#   'Edad': 22,
#   'Nacimiento': 2000.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 1.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2022-2023',
#   'Valor de mercado': 25000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc41'),
#   'Jugador': 'Alejandro Rodríguez',
#   'Pais': 'ESP',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Empoli',
#   'Edad': 27,
#   'Nacimiento': 1991.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 25.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.1,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2018-2019',
#   'Valor de mercado': 1500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc42'),
#   'Jugador': 'Aleksa Terzić',
#   'Pais': 'SRB',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Fiorentina',
#   'Edad': 22,
#   'Nacimiento': 1999.0,
#   'PJ': 12.666666666666666,
#   'Titular': 3.0,
#   'Mín': 405.6666666666667,
#   'Goles': 0.3333333333333333,
#   'Asistencias': 0.6666666666666666,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.1333333333333333,
#   'Asistencias Esperadas': 0.7666666666666666,
#   'Temporada': '2019-2020',
#   'Valor de mercado': 4000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc43'),
#   'Jugador': 'Aleksandar Dragović',
#   'Pais': 'AUT',
#   'Posicion': 'Defensa',
#   'Equipo': 'Leicester City',
#   'Edad': 26,
#   'Nacimiento': 1991.0,
#   'PJ': 11.0,
#   'Titular': 7.0,
#   'Mín': 769.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 2.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.1,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 4500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc44'),
#   'Jugador': 'Aleksandar Jovanović',
#   'Pais': 'SRB',
#   'Posicion': 'PO',
#   'Equipo': 'Huesca',
#   'Edad': 25,
#   'Nacimiento': 1992.0,
#   'PJ': 12.0,
#   'Titular': 12.0,
#   'Mín': 1080.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2018-2019',
#   'Valor de mercado': 800000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc45'),
#   'Jugador': 'Aleksandar Katai',
#   'Pais': 'SRB',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Alavés',
#   'Edad': 26,
#   'Nacimiento': 1991.0,
#   'PJ': 3.0,
#   'Titular': 0.0,
#   'Mín': 55.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.1,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 4500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc47'),
#   'Jugador': 'Aleksandar Sedlar',
#   'Pais': 'SRB',
#   'Posicion': 'Defensa',
#   'Equipo': 'Mallorca',
#   'Edad': 29,
#   'Nacimiento': 1991.0,
#   'PJ': 11.0,
#   'Titular': 6.0,
#   'Mín': 609.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 4.0,
#   'Tarjetas Rojas': 1.0,
#   'Goles Esperados': 0.05,
#   'Asistencias Esperadas': 0.05,
#   'Temporada': '2019-2020',
#   'Valor de mercado': 500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc48'),
#   'Jugador': 'Aleksandar Trajkovski',
#   'Pais': 'MKD',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Mallorca',
#   'Edad': 26,
#   'Nacimiento': 1992.0,
#   'PJ': 14.0,
#   'Titular': 1.0,
#   'Mín': 330.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.5,
#   'Asistencias Esperadas': 1.2,
#   'Temporada': '2019-2020',
#   'Valor de mercado': 450000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc49'),
#   'Jugador': 'Aleksander Buksa',
#   'Pais': 'POL',
#   'Posicion': 'Delantero',
#   'Equipo': 'Genoa',
#   'Edad': 18,
#   'Nacimiento': 2003.0,
#   'PJ': 4.0,
#   'Titular': 0.0,
#   'Mín': 63.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2021-2022',
#   'Valor de mercado': 700000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc4a'),
#   'Jugador': 'Aleksandr Kokorin',
#   'Pais': 'RUS',
#   'Posicion': 'Delantero',
#   'Equipo': 'Fiorentina',
#   'Edad': 30,
#   'Nacimiento': 1991.0,
#   'PJ': 5.0,
#   'Titular': 0.0,
#   'Mín': 74.5,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2020-2021',
#   'Valor de mercado': 1000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc4b'),
#   'Jugador': 'Aleksei Miranchuk',
#   'Pais': 'RUS',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Atalanta',
#   'Edad': 26,
#   'Nacimiento': 1995.0,
#   'PJ': 24.33333333333333,
#   'Titular': 11.666666666666666,
#   'Mín': 1178.6666666666667,
#   'Goles': 3.333333333333333,
#   'Asistencias': 4.0,
#   'Goles+Asistencias': 7.333333333333333,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 1.8333333333333333,
#   'Asistencias Esperadas': 2.866666666666667,
#   'Temporada': '2020-2021',
#   'Valor de mercado': 9000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc4c'),
#   'Jugador': 'Alen Halilović',
#   'Pais': 'CRO',
#   'Posicion': 'Delantero',
#   'Equipo': 'Las Palmas',
#   'Edad': 21,
#   'Nacimiento': 1996.0,
#   'PJ': 20.0,
#   'Titular': 16.0,
#   'Mín': 1304.0,
#   'Goles': 2.0,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 3.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 1.0,
#   'Goles Esperados': 1.6,
#   'Asistencias Esperadas': 1.8,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 1000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc4e'),
#   'Jugador': 'Alessandro Berardi',
#   'Pais': 'ITA',
#   'Posicion': 'PO',
#   'Equipo': 'Hellas Verona',
#   'Edad': 30,
#   'Nacimiento': 1991.0,
#   'PJ': 1.0,
#   'Titular': 0.5,
#   'Mín': 59.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2020-2021',
#   'Valor de mercado': 50000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7edc4f'),
# ...
#   'Asistencias': 1.3333333333333333,
#   'Goles+Asistencias': 1.6666666666666667,
#   'Tarjetas Amarillas': 5.333333333333333,
#   'Tarjetas Rojas': 1.0,
#   'Goles Esperados': 0.9,
#   'Asistencias Esperadas': 0.7000000000000001,
#   'Temporada': '2020-2021',
#   'Valor de mercado': 4000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0bb'),
#   'Jugador': 'Ilario Monterisi',
#   'Pais': 'ITA',
#   'Posicion': 'Defensa',
#   'Equipo': 'Lecce',
#   'Edad': 17,
#   'Nacimiento': 2001.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 3.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2019-2020',
#   'Valor de mercado': 1500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0bc'),
#   'Jugador': 'Ilias Akhomach',
#   'Pais': 'ESP',
#   'Posicion': 'Delantero',
#   'Equipo': 'Barcelona',
#   'Edad': 17,
#   'Nacimiento': 2004.0,
#   'PJ': 2.0,
#   'Titular': 2.0,
#   'Mín': 124.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.1,
#   'Asistencias Esperadas': 0.6,
#   'Temporada': '2021-2022',
#   'Valor de mercado': 3000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0bd'),
#   'Jugador': 'Ilija Nestorovski',
#   'Pais': 'MKD',
#   'Posicion': 'Delantero',
#   'Equipo': 'Udinese',
#   'Edad': 32,
#   'Nacimiento': 1990.0,
#   'PJ': 19.5,
#   'Titular': 6.25,
#   'Mín': 694.5,
#   'Goles': 2.0,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 3.0,
#   'Tarjetas Amarillas': 2.25,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 2.7,
#   'Asistencias Esperadas': 1.0,
#   'Temporada': '2019-2020',
#   'Valor de mercado': 400000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0c1'),
#   'Jugador': 'Imanol Sarriegi',
#   'Pais': 'ESP',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Eibar',
#   'Edad': 22,
#   'Nacimiento': 1995.0,
#   'PJ': 3.0,
#   'Titular': 0.0,
#   'Mín': 41.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 200000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0c2'),
#   'Jugador': 'Imoh Ezekiel',
#   'Pais': 'NGA',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Las Palmas',
#   'Edad': 23,
#   'Nacimiento': 1993.0,
#   'PJ': 10.0,
#   'Titular': 5.0,
#   'Mín': 469.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 1.1,
#   'Asistencias Esperadas': 0.1,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 200000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0c3'),
#   'Jugador': 'Imran Louza',
#   'Pais': 'MAR',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Watford',
#   'Edad': 22,
#   'Nacimiento': 1999.0,
#   'PJ': 20.0,
#   'Titular': 17.0,
#   'Mín': 1416.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 6.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 1.2,
#   'Asistencias Esperadas': 1.1,
#   'Temporada': '2021-2022',
#   'Valor de mercado': 9000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0c4'),
#   'Jugador': 'Indiana Vassilev',
#   'Pais': 'USA',
#   'Posicion': 'Delantero',
#   'Equipo': 'Aston Villa',
#   'Edad': 18,
#   'Nacimiento': 2001.0,
#   'PJ': 4.0,
#   'Titular': 0.0,
#   'Mín': 51.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2019-2020',
#   'Valor de mercado': 1500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0c5'),
#   'Jugador': 'Ionuț Radu',
#   'Pais': 'ROU',
#   'Posicion': 'PO',
#   'Equipo': 'Genoa',
#   'Edad': 25,
#   'Nacimiento': 1997.0,
#   'PJ': 12.4,
#   'Titular': 12.2,
#   'Mín': 1107.0,
#   'Goles': 0.0,
#   'Asistencias': 0.2,
#   'Goles+Asistencias': 0.2,
#   'Tarjetas Amarillas': 0.2,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.12,
#   'Temporada': '2018-2019',
#   'Valor de mercado': 3500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0c6'),
#   'Jugador': 'Isaac Carcelen',
#   'Pais': 'ESP',
#   'Posicion': 'Defensa',
#   'Equipo': 'Cádiz',
#   'Edad': 29,
#   'Nacimiento': 1993.0,
#   'PJ': 28.0,
#   'Titular': 24.33333333333333,
#   'Mín': 2108.0,
#   'Goles': 0.0,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 3.0,
#   'Tarjetas Rojas': 1.0,
#   'Goles Esperados': 0.3666666666666667,
#   'Asistencias Esperadas': 0.9666666666666668,
#   'Temporada': '2020-2021',
#   'Valor de mercado': 1500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0c7'),
#   'Jugador': 'Isaac Cofie',
#   'Pais': 'GHA',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Genoa',
#   'Edad': 25,
#   'Nacimiento': 1991.0,
#   'PJ': 12.0,
#   'Titular': 6.0,
#   'Mín': 591.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.2,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 200000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0c8'),
#   'Jugador': 'Isaac Hayden',
#   'Pais': 'ENG',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Newcastle Utd',
#   'Edad': 26,
#   'Nacimiento': 1995.0,
#   'PJ': 23.6,
#   'Titular': 19.2,
#   'Mín': 1680.0,
#   'Goles': 0.8,
#   'Asistencias': 1.2,
#   'Goles+Asistencias': 2.0,
#   'Tarjetas Amarillas': 5.4,
#   'Tarjetas Rojas': 0.4,
#   'Goles Esperados': 0.8400000000000001,
#   'Asistencias Esperadas': 1.1,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 3500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0c9'),
#   'Jugador': 'Isaac Mbenza',
#   'Pais': 'BEL',
#   'Posicion': 'Delantero',
#   'Equipo': 'Huddersfield',
#   'Edad': 22,
#   'Nacimiento': 1996.0,
#   'PJ': 22.0,
#   'Titular': 10.0,
#   'Mín': 986.0,
#   'Goles': 1.0,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 2.0,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 1.0,
#   'Asistencias Esperadas': 0.9,
#   'Temporada': '2018-2019',
#   'Valor de mercado': 2200000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0cb'),
#   'Jugador': 'Isaac Price',
#   'Pais': 'NIR',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Everton',
#   'Edad': 18,
#   'Nacimiento': 2003.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 23.5,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.5,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.05,
#   'Asistencias Esperadas': 0.05,
#   'Temporada': '2021-2022',
#   'Valor de mercado': 700000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0cc'),
#   'Jugador': 'Isaac Success',
#   'Pais': 'NGA',
#   'Posicion': 'Delantero',
#   'Equipo': 'Watford',
#   'Edad': 26,
#   'Nacimiento': 1996.0,
#   'PJ': 19.2,
#   'Titular': 9.6,
#   'Mín': 868.0,
#   'Goles': 0.8,
#   'Asistencias': 2.8,
#   'Goles+Asistencias': 3.6,
#   'Tarjetas Amarillas': 2.0,
#   'Tarjetas Rojas': 0.2,
#   'Goles Esperados': 1.9,
#   'Asistencias Esperadas': 2.46,
#   'Temporada': '2018-2019',
#   'Valor de mercado': 4000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0cd'),
#   'Jugador': 'Isak Hien',
#   'Pais': 'SWE',
#   'Posicion': 'Defensa',
#   'Equipo': 'Hellas Verona',
#   'Edad': 23,
#   'Nacimiento': 1999.0,
#   'PJ': 32.0,
#   'Titular': 28.0,
#   'Mín': 2607.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 9.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.3,
#   'Asistencias Esperadas': 0.1,
#   'Temporada': '2022-2023',
#   'Valor de mercado': 9000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0ce'),
#   'Jugador': 'Isco',
#   'Pais': 'ESP',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Real Madrid',
#   'Edad': 30,
#   'Nacimiento': 1992.0,
#   'PJ': 21.83333333333333,
#   'Titular': 11.333333333333334,
#   'Mín': 1030.8333333333333,
#   'Goles': 2.0,
#   'Asistencias': 2.5,
#   'Goles+Asistencias': 4.5,
#   'Tarjetas Amarillas': 2.1666666666666665,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 2.533333333333333,
#   'Asistencias Esperadas': 2.583333333333333,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 8000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0cf'),
#   'Jugador': 'Islam Slimani',
#   'Pais': 'ALG',
#   'Posicion': 'Delantero',
#   'Equipo': 'Leicester City',
#   'Edad': 32,
#   'Nacimiento': 1988.0,
#   'PJ': 5.666666666666667,
#   'Titular': 1.0,
#   'Mín': 133.66666666666666,
#   'Goles': 0.3333333333333333,
#   'Asistencias': 0.3333333333333333,
#   'Goles+Asistencias': 0.6666666666666666,
#   'Tarjetas Amarillas': 0.3333333333333333,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.5333333333333333,
#   'Asistencias Esperadas': 0.2333333333333333,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 1500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0d0'),
#   'Jugador': 'Isma Ruiz',
#   'Pais': 'ESP',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Granada',
#   'Edad': 20,
#   'Nacimiento': 2001.0,
#   'PJ': 4.5,
#   'Titular': 2.0,
#   'Mín': 175.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.5,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.05,
#   'Asistencias Esperadas': 0.05,
#   'Temporada': '2020-2021',
#   'Valor de mercado': 400000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0d4'),
#   'Jugador': 'Issa Bah',
#   'Pais': 'LUX',
#   'Posicion': 'Delantero',
#   'Equipo': 'Venezia',
#   'Edad': 19,
#   'Nacimiento': 2002.0,
#   'PJ': 1.0,
#   'Titular': 0.0,
#   'Mín': 9.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2021-2022',
#   'Valor de mercado': 75000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0d6'),
#   'Jugador': 'Iuri Medeiros',
#   'Pais': 'POR',
#   'Posicion': 'Delantero',
#   'Equipo': 'Genoa',
#   'Edad': 24,
#   'Nacimiento': 1994.0,
#   'PJ': 6.5,
#   'Titular': 4.5,
#   'Mín': 373.5,
#   'Goles': 1.0,
#   'Asistencias': 0.5,
#   'Goles+Asistencias': 1.5,
#   'Tarjetas Amarillas': 0.5,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.5,
#   'Asistencias Esperadas': 0.95,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 6000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0d7'),
#   'Jugador': 'Ivan Cavaleiro',
#   'Pais': 'POR',
#   'Posicion': 'Delantero',
#   'Equipo': 'Wolves',
#   'Edad': 26,
#   'Nacimiento': 1993.0,
#   'PJ': 29.5,
#   'Titular': 16.5,
#   'Mín': 1582.5,
#   'Goles': 3.0,
#   'Asistencias': 0.5,
#   'Goles+Asistencias': 3.5,
#   'Tarjetas Amarillas': 1.5,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 4.300000000000001,
#   'Asistencias Esperadas': 2.1,
#   'Temporada': '2018-2019',
#   'Valor de mercado': 2500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0d9'),
#   'Jugador': 'Ivan Perišić',
#   'Pais': 'CRO',
#   'Posicion': 'Defensa',
#   'Equipo': 'Tottenham',
#   'Edad': 33,
#   'Nacimiento': 1989.0,
#   'PJ': 34.4,
#   'Titular': 29.0,
#   'Mín': 2547.6,
#   'Goles': 6.4,
#   'Asistencias': 5.4,
#   'Goles+Asistencias': 11.8,
#   'Tarjetas Amarillas': 4.4,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 6.1,
#   'Asistencias Esperadas': 6.779999999999999,
#   'Temporada': '2022-2023',
#   'Valor de mercado': 4000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0db'),
#   'Jugador': 'Ivan Radovanović',
#   'Pais': 'SRB',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Chievo',
#   'Edad': 33,
#   'Nacimiento': 1988.0,
#   'PJ': 20.857142857142858,
#   'Titular': 18.142857142857142,
#   'Mín': 1628.2857142857142,
#   'Goles': 0.2857142857142857,
#   'Asistencias': 0.4285714285714285,
#   'Goles+Asistencias': 0.7142857142857143,
#   'Tarjetas Amarillas': 4.142857142857143,
#   'Tarjetas Rojas': 0.2857142857142857,
#   'Goles Esperados': 0.6714285714285715,
#   'Asistencias Esperadas': 0.5714285714285714,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 400000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0dc'),
#   'Jugador': 'Ivan Rakitić',
#   'Pais': 'CRO',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Barcelona',
#   'Edad': 34,
#   'Nacimiento': 1988.0,
#   'PJ': 33.833333333333336,
#   'Titular': 24.666666666666668,
#   'Mín': 2211.6666666666665,
#   'Goles': 2.333333333333333,
#   'Asistencias': 4.0,
#   'Goles+Asistencias': 6.333333333333333,
#   'Tarjetas Amarillas': 4.833333333333333,
#   'Tarjetas Rojas': 0.3333333333333333,
#   'Goles Esperados': 3.0666666666666664,
#   'Asistencias Esperadas': 2.216666666666667,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 4000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0de'),
#   'Jugador': 'Ivan Šaponjić',
#   'Pais': 'SRB',
#   'Posicion': 'Defensa',
#   'Equipo': 'Atlético Madrid',
#   'Edad': 22,
#   'Nacimiento': 1997.0,
#   'PJ': 5.5,
#   'Titular': 1.5,
#   'Mín': 197.0,
#   'Goles': 0.5,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.5,
#   'Tarjetas Amarillas': 1.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 1.25,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2019-2020',
#   'Valor de mercado': 650000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0e0'),
#   'Jugador': 'Ivo Grbić',
#   'Pais': 'CRO',
#   'Posicion': 'PO',
#   'Equipo': 'Atlético Madrid',
#   'Edad': 26,
#   'Nacimiento': 1996.0,
#   'PJ': 12.0,
#   'Titular': 10.0,
#   'Mín': 922.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 3.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2022-2023',
#   'Valor de mercado': 3500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0e1'),
#   'Jugador': 'Ivor Pandur',
#   'Pais': 'CRO',
#   'Posicion': 'PO',
#   'Equipo': 'Hellas Verona',
#   'Edad': 21,
#   'Nacimiento': 2000.0,
#   'PJ': 3.5,
#   'Titular': 3.5,
#   'Mín': 301.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0,
#   'Temporada': '2020-2021',
#   'Valor de mercado': 2000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0e2'),
#   'Jugador': 'Iván Alejo',
#   'Pais': 'ESP',
#   'Posicion': 'Centrocampista',
#   'Equipo': 'Eibar',
#   'Edad': 27,
#   'Nacimiento': 1995.0,
#   'PJ': 19.8,
#   'Titular': 9.2,
#   'Mín': 890.2,
#   'Goles': 0.8,
#   'Asistencias': 1.4,
#   'Goles+Asistencias': 2.2,
#   'Tarjetas Amarillas': 6.4,
#   'Tarjetas Rojas': 0.4,
#   'Goles Esperados': 0.8400000000000001,
#   'Asistencias Esperadas': 1.5399999999999998,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 1200000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0e3'),
#   'Jugador': 'Iván Balliu',
#   'Pais': 'ALB',
#   'Posicion': 'Defensa',
#   'Equipo': 'Rayo Vallecano',
#   'Edad': 30,
#   'Nacimiento': 1992.0,
#   'PJ': 36.0,
#   'Titular': 36.0,
#   'Mín': 3189.5,
#   'Goles': 0.5,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 1.5,
#   'Tarjetas Amarillas': 8.0,
#   'Tarjetas Rojas': 0.5,
#   'Goles Esperados': 0.6,
#   'Asistencias Esperadas': 3.15,
#   'Temporada': '2021-2022',
#   'Valor de mercado': 4000000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0e4'),
#   'Jugador': 'Iván Cuéllar',
#   'Pais': 'ESP',
#   'Posicion': 'PO',
#   'Equipo': 'Leganés',
#   'Edad': 35,
#   'Nacimiento': 1984.0,
#   'PJ': 32.0,
#   'Titular': 32.0,
#   'Mín': 2878.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 4.333333333333333,
#   'Tarjetas Rojas': 0.3333333333333333,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.0333333333333333,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 100000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0e6'),
#   'Jugador': 'Iván López',
#   'Pais': 'ESP',
#   'Posicion': 'Defensa',
#   'Equipo': 'Levante',
#   'Edad': 23,
#   'Nacimiento': 1993.0,
#   'PJ': 3.0,
#   'Titular': 3.0,
#   'Mín': 173.0,
#   'Goles': 0.0,
#   'Asistencias': 1.0,
#   'Goles+Asistencias': 1.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.0,
#   'Asistencias Esperadas': 0.6,
#   'Temporada': '2017-2018',
#   'Valor de mercado': 2500000.0},
#  {'_id': ObjectId('656eec6d5cc59deefd7ee0e7'),
#   'Jugador': 'Iván Marcano',
#   'Pais': 'ESP',
#   'Posicion': 'Defensa',
#   'Equipo': 'Roma',
#   'Edad': 31,
#   'Nacimiento': 1987.0,
#   'PJ': 10.0,
#   'Titular': 9.0,
#   'Mín': 810.0,
#   'Goles': 0.0,
#   'Asistencias': 0.0,
#   'Goles+Asistencias': 0.0,
#   'Tarjetas Amarillas': 0.0,
#   'Tarjetas Rojas': 0.0,
#   'Goles Esperados': 0.2,
#   'Asistencias Esperadas': 0.5,
#   'Temporada': '2018-2019',
#   'Valor de mercado': 500000.0},
#  ...]
