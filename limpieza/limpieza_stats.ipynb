# %% [markdown]
# # Limpieza Stats

# %%
import pandas as pd
import numpy as np

# %%
# Limpeiza dataframe de jugadores_2023
stats = pd.read_csv('../csv/csv_limpios/stats_completo.csv')

# %% [markdown]
# # Exploro stats

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3340 entries, 0 to 3339
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             3340 non-null   int64
#  1   Jugador                3340 non-null   object
#  2   País                   3340 non-null   object
#  3   Posc                   3340 non-null   object
#  4   Equipo                 3340 non-null   object
#  5   Edad                   3340 non-null   int64
#  6   Nacimiento             3340 non-null   int64
#  7   PJ                     3340 non-null   int64
#  8   Titular                3340 non-null   int64
#  9   Mín                    3340 non-null   int64
#  10  Gls.                   3340 non-null   int64
#  11  Asistencias            3340 non-null   int64
#  12  Goles+Asistencias      3340 non-null   int64
#  13  Tarjetas Amarillas     3340 non-null   int64
# ...

# %%
stats.head()
# Out:
#    Unnamed: 0             Jugador País            Posc         Equipo  Edad  \
# 0           0               Abner  BRA         Defensa          Betis    22
# 1           1       Álvaro Aceves  ESP              PO     Valladolid    19
# 2           2        Marcos Acuña  ARG         Defensa        Sevilla    30
# 3           3  Julen Agirrezabala  ESP              PO  Athletic Club    21
# 4           4       Álvaro Aguado  ESP  Centrocampista     Valladolid    26
#
#    Nacimiento  PJ  Titular   Mín  Gls.  Asistencias  Goles+Asistencias  \
# 0        2000  13        7   607     0            0                  0
# 1        2003   1        0    13     0            0                  0
# 2        1991  30       21  1912     3            2                  5
# 3        2000   8        7   675     0            0                  0
# 4        1996  34       18  1888     1            2                  3
#
#    Tarjetas Amarillas  Tarjetas Rojas  Goles Esperados  Asistencias Esperadas  \
# ...

# %%
stats.shape
# Out:
# (3340, 18)

# %% [markdown]
# # Limpieza

# %%
# Averiguo si hay nulos
stats.isnull().sum()
# Out:
# Unnamed: 0               0
# Jugador                  0
# País                     0
# Posc                     0
# Equipo                   0
# Edad                     0
# Nacimiento               0
# PJ                       0
# Titular                  0
# Mín                      0
# Gls.                     0
# Asistencias              0
# Goles+Asistencias        0
# Tarjetas Amarillas       0
# Tarjetas Rojas           0
# Goles Esperados          0
# Asistencias Esperadas    0
# Valor Mercado            0
# dtype: int64

# %%
# Veo la columna valor de mercado para ver cuando con '-' hay
stats[stats['Valor Mercado'] == '-']
# Out:
#       Unnamed: 0            Jugador País            Posc           Equipo  \
# 17            17      Ángel Algobia  ESP  Centrocampista           Getafe
# 27            27       Marcos André  BRA       Delantero         Valencia
# 30            30       José Antonio  ESP  Centrocampista            Cádiz
# 37            37      Ricard Artero  ESP  Centrocampista           Girona
# 57            57  Rodrigo Battaglia  ARG  Centrocampista         Mallorca
# ...          ...                ...  ...             ...              ...
# 3315        3315   Thomas Vermaelen  BEL         Defensa        Barcelona
# 3324        3324         Dídac Vilà  ESP         Defensa         Espanyol
# 3326        3326             Vitolo  ESP  Centrocampista  Atlético Madrid
# 3334        3334        Simone Zaza  ITA       Delantero         Valencia
# 3339        3339     David Zurutuza  ESP  Centrocampista    Real Sociedad
#
#       Edad  Nacimiento  PJ  Titular   Mín  Gls.  Asistencias  \
# ...

# %%
# Elimino las filas que tienen '-' en la columna valor de mercado
stats = stats[stats['Valor Mercado'] != '-']

# %%
# Elimino la columna jugadores ya que en el modelo predictivo solo importan las estadisticas
#stats = stats.drop(['Jugador'], axis=1)

# %%
#Dropeo la columna unnamed
stats = stats.drop(['Unnamed: 0'], axis=1)

# %%
#reseteo el index
stats.reset_index(drop=True, inplace=True)

# %%
stats
# Out:
#                  Jugador País            Posc         Equipo  Edad  \
# 0                  Abner  BRA         Defensa          Betis    22
# 1          Álvaro Aceves  ESP              PO     Valladolid    19
# 2           Marcos Acuña  ARG         Defensa        Sevilla    30
# 3     Julen Agirrezabala  ESP              PO  Athletic Club    21
# 4          Álvaro Aguado  ESP  Centrocampista     Valladolid    26
# ...                  ...  ...             ...            ...   ...
# 2980       Joseba Zaldúa  ESP         Defensa        Leganés    25
# 2981       Nabil El Zhar  MAR       Delantero        Leganés    30
# 2982         Enzo Zidane  ESP  Centrocampista         Alavés    22
# 2983         Luca Zidane  FRA              PO    Real Madrid    19
# 2984       Igor Zubeldia  ESP  Centrocampista  Real Sociedad    20
#
#       Nacimiento  PJ  Titular   Mín  Gls.  Asistencias  Goles+Asistencias  \
# 0           2000  13        7   607     0            0                  0
# ...

# %%
def custom_agg(x):
    if x.name == 'Edad':
        return np.max(x)
    else:
        return np.mean(x)

stats.groupby('Jugador').agg(custom_agg)
# Out:
# C:\Users\matia\AppData\Local\Temp\ipykernel_111372\2888543045.py:7: FutureWarning: ['País', 'Posc', 'Equipo', 'Valor Mercado'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   stats.groupby('Jugador').agg(custom_agg)
#                        Edad  Nacimiento         PJ    Titular          Mín  \
# Jugador
# Aarón Escandell          25      1995.0   4.000000   3.666667   334.666667
# Aarón Martín             23      1997.0  25.500000  24.000000  2177.500000
# Abdallahi Mahmoud        20      2000.0   2.500000   1.000000   109.000000
# Abdessamad Ezzalzouli    20      2001.0  19.000000  12.500000  1042.000000
# Abdoulay Diaby           29      1991.0   1.000000   0.000000    18.000000
# ...                     ...         ...        ...        ...          ...
# Óscar Trejo              34      1988.0  30.666667  24.666667  1972.000000
# ...

# %% [markdown]
# # Exporto el dataframe

# %%
stats.to_csv('../csv/csv_limpios/stats_completo_lp.csv', index=False)
